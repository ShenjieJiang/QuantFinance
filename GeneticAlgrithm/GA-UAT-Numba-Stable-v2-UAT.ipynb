# %%
import deap
import json
import operator
import deap.tools as tools
import deap.base as base
import numpy as np
import random
import inspect
import pandas as pd
from functools import partial
import sys
from deap import base, creator, tools, gp, algorithms
from sklearn.linear_model import LinearRegression
import multiprocessing
from joblib import Parallel, delayed
from tqdm import tqdm
from numba.typed import List 
from npeet.entropy_estimators import mi
import deap.tools as tools
import warnings
import swifter
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
import cupyx
import torch
import numba
from numba import jit
from numba import njit

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
warnings.simplefilter("ignore")

def load_data(data):
    data = pd.read_pickle(f'D:redata/DEAP/ad_hoc_prod/fields_full/{data}.pk')
    data = data.loc['2017':]
    data = data.stack()
    data = data.replace(0,np.nan)
    return data
    
adj_return = load_data("adj_return")
adj_close = load_data("adj_close")
adj_open = load_data("adj_open")
adj_high = load_data("adj_high")
adj_low = load_data("adj_low")
close = load_data("close")
open = load_data("open")
high = load_data("high")
low = load_data("low")
num_trades = load_data("num_trades")
total_turnover = load_data("total_turnover")
turnover_rate = load_data("turnover_rate")
circulation_a = load_data("circulation_a")
total_a = load_data("total_a")
circulation_market_value = load_data("circulation_market_value")
volume = load_data("volume")

data_origin_factors = pd.concat([open, high, low, close, volume, total_turnover, turnover_rate, adj_return], axis=1)
data_origin_factors .columns = ['open', 'high', 'low', 'close', 'volume', 'total_turnover', 'turnover_rate', 'adj_return']

def calculate_twap(df):
    df['twap'] = (df['high'] + df['low'] + df['close'] + df['open']) / 4
    return df['twap']

def calculate_vwap(df):
    df['vwap'] = df['total_turnover']/df['volume']
    return df['vwap']

data_origin_factors['twap'] = data_origin_factors.groupby('ticker', group_keys=False).apply(calculate_twap)
data_origin_factors['vwap'] = data_origin_factors.groupby('ticker', group_keys=False).apply(calculate_vwap)

# 设置target为隔夜收益率,下一天的收盘买，下二天的收盘卖
adj_close_stk = pd.read_pickle('D:redata/DEAP/ad_hoc_prod/fields_full/adj_close.pk')
adj_open_stk = pd.read_pickle('D:redata/DEAP/ad_hoc_prod/fields_full/adj_open.pk')

limit_down = pd.read_pickle('D:redata/DEAP/ad_hoc_prod/fields_full/limit_down.pk') #跌停
limit_down = limit_down[(limit_down.index >= '2017-01-01')]
limit_up = pd.read_pickle('D:redata/DEAP/ad_hoc_prod/fields_full/limit_up.pk') #涨停
limit_up = limit_up[(limit_up.index >= '2017-01-01')]

halt_status = pd.read_pickle('D:redata/DEAP/ad_hoc_prod/fields_full/halt_status.pk') #停牌
halt_status = halt_status[(halt_status.index >= '2017-01-01')]
st_status = pd.read_pickle('D:redata/DEAP/ad_hoc_prod/fields_full/st_status.pk') #st
st_status = st_status[(st_status.index >= '2017-01-01')]
st_status = st_status.replace(True,np.nan).replace(False,True)
halt_status = halt_status.replace(True,np.nan).replace(False,True)

adj_target_ret_o1o2 = adj_open_stk.shift(-2)/adj_open_stk.shift(-1) - 1
adj_target_ret_o1o2 = adj_target_ret_o1o2.replace(np.inf,np.nan).replace(-np.inf,np.nan)

# # 设置target为隔夜收益率,下一天的收盘买，下五天的收盘卖
# adj_target_ret_o1o5 = adj_open_stk.shift(-5)/adj_open_stk.shift(-1) - 1
# adj_target_ret_o1o5 = adj_target_ret_o1o5.replace(np.inf,np.nan).replace(-np.inf,np.nan)

target_pre = pd.DataFrame(adj_target_ret_o1o2.stack())
target_pre.columns = ['target']

data_merged = pd.merge(data_origin_factors, target_pre, on=['date', 'ticker'], how='left')
data_merged = data_merged.dropna(axis = 0)

# %%
def compute_condition(new_stk):
    drop_new_stk = adj_open.rolling(window=new_stk, min_periods=new_stk).mean()
    drop_new_stk = ~np.isnan(drop_new_stk)
    drop_new_stk = drop_new_stk.unstack()
    df = st_status * halt_status * drop_new_stk
    df = df.replace(True, 1).replace(False, np.nan)
    return df.loc['2017':]

final_universe = compute_condition(new_stk = 20) ##剔除20日内新股，st，halt

# === 数据集拆分 (7:3) ===
full_data = data_merged.loc['2017-01-03': '2024-12-31']
# 选择2022年以前的数据作为训练集
train_data = full_data[full_data.index.get_level_values('date') <= '2021-06-30']

# 选择2022年及以后的数据作为验证集
val_data = full_data[full_data.index.get_level_values('date') > '2021-06-30']

# Define data and target
train_data_set = train_data.iloc[:, :-1]
train_data_target = train_data.iloc[:, -1:]

val_data_set = val_data.iloc[:, :-1]
val_data_target = val_data.iloc[:, -1:]

target = full_data.iloc[:, -1:]
target_clean = target['target'].unstack()
target_clean = target_clean.replace([np.inf, -np.inf], np.nan)
target_clean = (target_clean * final_universe)
target_clean = target_clean.dropna(how='all',axis=0)
target_clean = target_clean.drop_duplicates()

train_clean_target = target_clean[target_clean.index.get_level_values('date') <= '2021-06-30']
val_clean_target = target_clean[target_clean.index.get_level_values('date') > '2021-06-30']
train_clean_rank_target = train_clean_target.rank(ascending=True, axis=1)
val_clean_rank_target = val_clean_target.rank(ascending=True, axis=1)

#临时，没做分层
full_data_factors = full_data.iloc[:, :-1]
full_data_clean_rank_target = target_clean.rank(axis=1, ascending=True)

# %%
from math import pow
def ensure_multiindex(x: pd.Series, template: pd.Series) -> pd.Series:
    if not isinstance(x.index, pd.MultiIndex):
        x.index = template.index
    else:
        x = x.reindex(template.index)
    return x

# -------------------- Numba核心滚动函数 --------------------

@njit
def rolling_mean(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]
        
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        if (i - start_pos + 1) >= window:
            window_start = i - window + 1
            s = 0.0
            count = 0
            for j in range(window_start, i + 1):
                if not np.isnan(values[j]):
                    s += values[j]
                    count += 1
            if count > 0:
                result[i] = s / count
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result
    
@njit
def rolling_std(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)

    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]
        
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        if (i - start_pos + 1) >= window:
            window_start = i - window + 1
            s = 0.0
            count = 0
            for j in range(window_start, i + 1):
                if not np.isnan(values[j]):
                    s += values[j]
                    count += 1

            if count > 1:
                mean = s / count
                var = 0.0
                for j in range(window_start, i + 1):
                    if not np.isnan(values[j]):
                        var += (values[j] - mean) ** 2
                result[i] = (var / (count - 1)) ** 0.5
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result
    
@njit
def rolling_skew(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        if i - start_pos + 1 >= window:
            count = 0
            mean = 0.0
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    mean += val
                    count += 1
            if count == 0:
                result[i] = np.nan
                continue
            mean /= count

            # 计算方差和三阶矩
            m2 = 0.0
            m3 = 0.0
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    diff = val - mean
                    m2 += diff ** 2
                    m3 += diff ** 3
            m2 /= count
            m3 /= count

            if m2 > 0:
                skew = m3 / (m2 ** 1.5)
                result[i] = skew
            else:
                result[i] = 0.0
        else:
            result[i] = np.nan

    return result

@njit
def rolling_kurt(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        if i - start_pos + 1 >= window:
            count = 0
            mean = 0.0
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    mean += val
                    count += 1
            if count == 0:
                result[i] = np.nan
                continue
            mean /= count

            # 计算方差和四阶矩
            m2 = 0.0
            m4 = 0.0
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    diff = val - mean
                    m2 += diff ** 2
                    m4 += diff ** 4
            m2 /= count
            m4 /= count

            if m2 > 0:
                kurt = m4 / (m2 ** 2)
                result[i] = kurt
            else:
                result[i] = 0.0
        else:
            result[i] = np.nan

    return result

@njit
def rolling_prod(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker 切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 判断窗口是否满足
        if i - start_pos + 1 >= window:
            p = 1.0
            valid_count = 0

            # 计算乘积
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    p *= val
                    valid_count += 1

            if valid_count == window:
                result[i] = p
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result

@njit
def rolling_argmin(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]
    window_values = List.empty_list(np.float64)

    for i in range(n):
        current_ticker = tickers[i]

        # ticker 切换，重置起点
        if current_ticker != last_ticker:
            start_pos, last_ticker = i, current_ticker
            window_values.clear()

        # 收集有效值
        if not np.isnan(values[i]):
            window_values.append(values[i])

        # 判断窗口是否超出，清理旧值
        if i - start_pos + 1 > window:
            old_value = values[i - window]
            if not np.isnan(old_value):
                for idx in range(len(window_values)):
                    if window_values[idx] == old_value:
                        window_values.pop(idx)
                        break

        # 计算最小值及其索引
        if len(window_values) >= window:
            min_val = window_values[0]
            min_idx = 0
            for j in range(1, len(window_values)):
                if window_values[j] < min_val:
                    min_val = window_values[j]
                    min_idx = j
            result[i] = min_idx
        else:
            result[i] = np.nan

    return result

@njit
def rolling_argmax(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]
    window_values = List.empty_list(np.float64)

    for i in range(n):
        current_ticker = tickers[i]

        # ticker 切换，重置起点
        if current_ticker != last_ticker:
            start_pos, last_ticker = i, current_ticker
            window_values.clear()

        # 收集有效值
        if not np.isnan(values[i]):
            window_values.append(values[i])

        # 判断窗口是否超出，清理旧值
        if i - start_pos + 1 > window:
            old_value = values[i - window]
            if not np.isnan(old_value):
                for idx in range(len(window_values)):
                    if window_values[idx] == old_value:
                        window_values.pop(idx)
                        break

        # 计算最大值及其索引
        if len(window_values) >= window:
            max_val = window_values[0]
            max_idx = 0
            for j in range(1, len(window_values)):
                if window_values[j] > max_val:
                    max_val = window_values[j]
                    max_idx = j
            result[i] = max_idx
        else:
            result[i] = np.nan

    return result

@njit
def ts_zscore(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker 切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 判断窗口是否满足
        if i - start_pos + 1 >= window:
            sum_val = 0.0
            count = 0

            # 计算窗口内的均值
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    sum_val += val
                    count += 1

            if count > 1:
                mean = sum_val / count
                var_sum = 0.0

                # 计算窗口内的方差
                for j in range(i - window + 1, i + 1):
                    val = values[j]
                    if not np.isnan(val):
                        var_sum += (val - mean) ** 2

                std = (var_sum / (count - 1)) ** 0.5

                if std > 0.0 and not np.isnan(values[i]):
                    result[i] = (values[i] - mean) / std
                else:
                    result[i] = np.nan
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result

@njit
def rolling_sum(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker 切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 判断窗口是否满足
        if i - start_pos + 1 >= window:
            s = 0.0
            valid_count = 0

            # 计算窗口内的和
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    s += val
                    valid_count += 1

            # 如果窗口内有效值足够，则返回总和
            if valid_count == window:
                result[i] = s
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result

@njit
def rolling_max(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 窗口已满
        if i - start_pos + 1 >= window:
            max_value = -np.inf
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    max_value = max(max_value, val)
            result[i] = max_value if max_value != -np.inf else np.nan
        else:
            result[i] = np.nan

    return result

@njit
def rolling_min(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)

    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 窗口已满
        if i - start_pos + 1 >= window:
            min_value = np.inf
            for j in range(i - window + 1, i + 1):
                val = values[j]
                if not np.isnan(val):
                    min_value = min(min_value, val)
            result[i] = min_value if min_value != np.inf else np.nan
        else:
            result[i] = np.nan

    return result

@njit
def safe_delay(values, tickers, window):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)

    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 窗口是否满足
        if i - start_pos >= window:
            result[i] = values[i - window]
        else:
            result[i] = np.nan

    return result

@njit
def ts_argmaxmin(values, tickers, window):
    result_argmax = rolling_argmax(values, tickers, window)
    result_argmin = rolling_argmax(values, tickers, window)
    result = result_argmax - result_argmin
    result[np.isclose(result, 0.0)] = np.nan
    return result

@njit
def safe_delta(values, tickers, d):
    n = len(values)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)
    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker切换，重置起始位置
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        # 如果距离不足d天，跳过
        if i - start_pos < d:
            result[i] = np.nan
            continue

        v_now = values[i]
        v_before = values[i - d]

        if not np.isnan(v_now) and not np.isnan(v_before):
            result[i] = v_now - v_before
        else:
            result[i] = np.nan

    return result

@njit
def ts_rank(values, dates, window):
    n = len(values)
    result = np.full(n, np.nan)

    start_pos = 0
    last_date = dates[0]

    for i in range(n):
        current_date = dates[i]

        # 日期切换，重置起点
        if current_date != last_date:
            start_pos = i
            last_date = current_date

        # 判断窗口是否满足
        if i - start_pos + 1 >= window:
            valid_count = 0
            window_data = np.empty(window)

            for j in range(i - window + 1, i + 1):
                v = values[j]
                if not np.isnan(v):
                    window_data[valid_count] = v
                    valid_count += 1

            if valid_count > 0:
                sub_data = window_data[:valid_count]
                sorted_data = np.sort(sub_data)
                last_value = values[i]

                if not np.isnan(last_value):
                    # 使用 searchsorted 算 rank（从 1 开始）
                    rank = np.searchsorted(sorted_data, last_value, side='right')
                    result[i] = rank
                else:
                    result[i] = np.nan
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result

@njit
def ts_cov(x, y, tickers, window):
    n = len(x)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)

    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker 切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        if i - start_pos + 1 >= window:
            valid_count = 0
            sum_x = 0.0
            sum_y = 0.0

            for j in range(i - window + 1, i + 1):
                val_x = x[j]
                val_y = y[j]
                if not np.isnan(val_x) and not np.isnan(val_y):
                    sum_x += val_x
                    sum_y += val_y
                    valid_count += 1

            if valid_count >= window:
                mean_x = sum_x / valid_count
                mean_y = sum_y / valid_count

                cov_sum = 0.0
                for j in range(i - window + 1, i + 1):
                    val_x = x[j]
                    val_y = y[j]
                    if not np.isnan(val_x) and not np.isnan(val_y):
                        cov_sum += (val_x - mean_x) * (val_y - mean_y)

                result[i] = cov_sum / (valid_count - 1)
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result

@njit
def ts_corr(x, y, tickers, window):
    n = len(x)
    result = np.full(n, np.nan)
    tickers = tickers.astype(np.int64)

    start_pos = 0
    last_ticker = tickers[0]

    for i in range(n):
        current_ticker = tickers[i]

        # ticker切换，重置起点
        if current_ticker != last_ticker:
            start_pos = i
            last_ticker = current_ticker

        if i - start_pos + 1 >= window:
            valid_count = 0
            sum_x = 0.0
            sum_y = 0.0

            for j in range(i - window + 1, i + 1):
                val_x = x[j]
                val_y = y[j]
                if not np.isnan(val_x) and not np.isnan(val_y):
                    sum_x += val_x
                    sum_y += val_y
                    valid_count += 1

            if valid_count >= window:
                mean_x = sum_x / valid_count
                mean_y = sum_y / valid_count

                cov_sum = 0.0
                var_x_sum = 0.0
                var_y_sum = 0.0

                for j in range(i - window + 1, i + 1):
                    val_x = x[j]
                    val_y = y[j]
                    if not np.isnan(val_x) and not np.isnan(val_y):
                        dx = val_x - mean_x
                        dy = val_y - mean_y
                        cov_sum += dx * dy
                        var_x_sum += dx * dx
                        var_y_sum += dy * dy

                if var_x_sum > 0.0 and var_y_sum > 0.0:
                    std_x = (var_x_sum / (valid_count - 1)) ** 0.5
                    std_y = (var_y_sum / (valid_count - 1)) ** 0.5
                    result[i] = (cov_sum / (valid_count - 1)) / (std_x * std_y)
                else:
                    result[i] = np.nan
            else:
                result[i] = np.nan
        else:
            result[i] = np.nan

    return result
    
@njit
def safe_absolute(arr):
    result = np.abs(arr)
    return result

@njit
def safe_sqrt(arr):
    result = np.sqrt(np.abs(arr))
    return result

@njit
def safe_inverse(arr):
    result = np.empty_like(arr)
    for i in range(len(arr)):
        if arr[i] == 0 or np.isnan(arr[i]):
            result[i] = np.nan
        else:
            result[i] = 1.0 / arr[i]
    return result

@njit
def safe_log(arr):
    result = np.empty_like(arr)
    for i in range(len(arr)):
        if np.isnan(arr[i]):
            result[i] = np.nan
        else:
            result[i] = np.log1p(np.abs(arr[i]))
    return result

@njit
def x_rank(values, dates):
    result = np.empty(len(values))
    result[:] = np.nan

    start = 0
    n = len(values)

    for i in range(1, n):
        if dates[i] != dates[i - 1]:
            # rank from start to i-1
            idx = np.argsort(values[start:i])
            ranks = np.empty(i - start)
            for j in range(len(idx)):
                ranks[idx[j]] = j + 1  # rank starts from 1
            result[start:i] = ranks
            start = i

    # 最后一个 date 段落别忘了 rank
    idx = np.argsort(values[start:n])
    ranks = np.empty(n - start)
    for j in range(len(idx)):
        ranks[idx[j]] = j + 1
    result[start:n] = ranks

    return result

@njit
def safe_add(x, y):
    n = len(x)
    result = np.empty(n, dtype=np.float64)
    for i in range(n):
        a, b = x[i], y[i]
        if np.isnan(a) or np.isnan(b):
            result[i] = np.nan
        else:
            result[i] = a + b
    return result

@njit
def safe_sub(x, y):
    n = len(x)
    result = np.empty(n, dtype=np.float64)
    for i in range(n):
        a, b = x[i], y[i]
        if np.isnan(a) or np.isnan(b):
            result[i] = np.nan
        else:
            result[i] = a - b
    return result

@njit
def safe_mul(x, y):
    n = len(x)
    result = np.empty(n, dtype=np.float64)
    for i in range(n):
        a, b = x[i], y[i]
        if np.isnan(a) or np.isnan(b):
            result[i] = np.nan
        else:
            result[i] = a * b
    return result

@njit
def safe_div(x, y):
    n = len(x)
    result = np.empty(n, dtype=np.float64)
    for i in range(n):
        a, b = x[i], y[i]
        if np.isnan(a) or np.isnan(b) or b == 0:
            result[i] = np.nan
        else:
            result[i] = a / b
    return result
    
def rank_sub(x, y, cross_dates):
    if callable(x): x = x()
    result_x = x_rank(x, cross_dates)  # 只传需要的参数

    if callable(y): y = y()
    result_y = x_rank(y, cross_dates)  # 只传需要的参数

    result = result_x - result_y
    result[np.isclose(result, 0.0)] = np.nan

    return result

def rank_div(x, y, cross_dates):
    if callable(x): x = x()
    result_x = x_rank(x, cross_dates)  # 只传需要的参数

    if callable(y): y = y()
    result_y = x_rank(y, cross_dates)  # 只传需要的参数

    result = result_x / result_y
    result[np.isclose(result, 0.0)] = np.nan

    return result

@njit
def sigmoid(x):
    result = np.empty_like(x)
    for i in range(len(x)):
        result[i] = 1 / (1.0 + np.exp(-x[i]))
    return result


def ts_zscore_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = ts_zscore(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)
    
def rolling_skew_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_skew(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_mean_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_mean(x.values, ts_tickers, window)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_std_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_std(x.values, ts_tickers, window)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_kurt_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_kurt(x.values, ts_tickers, window)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_prod_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_prod(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_argmin_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_argmin(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_argmax_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_argmax(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_max_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_max(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_min_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_min(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rolling_sum_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = rolling_sum(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_delay_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = safe_delay(x.values, ts_tickers, window)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def ts_argmaxmin_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = ts_argmaxmin(x.values, ts_tickers, window)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_delta_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = safe_delta(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def ts_rank_expr(x, window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = ts_rank(x.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def ts_corr_expr(x,y,window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    if callable(y): y = y()
    y = y.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = ts_corr(x.values, y.values, ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def ts_cov_expr(x,y,window):
    if callable(x): x = x()
    x = x.sort_index(level=['ticker', 'date'], sort_remaining=True)
    if callable(y): y = y()
    y = y.sort_index(level=['ticker', 'date'], sort_remaining=True)
    result = ts_cov(x.values, y.values,  ts_tickers, window)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_add_expr(x, y):
    if callable(x): x = x()
    if callable(y): y = y()
    x_arr = x.values.astype(np.float64)
    y_arr = y.values.astype(np.float64)
    return pd.Series(safe_add(x_arr, y_arr), index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_sub_expr(x, y):
    if callable(x): x = x()
    if callable(y): y = y()
    x_arr = x.values.astype(np.float64)
    y_arr = y.values.astype(np.float64)
    return pd.Series(safe_sub(x_arr, y_arr), index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_mul_expr(x, y):
    if callable(x): x = x()
    if callable(y): y = y()
    x_arr = x.values.astype(np.float64)
    y_arr = y.values.astype(np.float64)
    return pd.Series(safe_mul(x_arr, y_arr), index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_div_expr(x, y):
    if callable(x): x = x()
    if callable(y): y = y()
    x_arr = x.values.astype(np.float64)
    y_arr = y.values.astype(np.float64)
    return pd.Series(safe_div(x_arr, y_arr), index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rank_div_expr(x, y):
    if callable(x): x = x()
    if callable(y): y = y()
    
    # 保持 Pandas Series 结构
    result = rank_div(x.values, y.values, cross_dates)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def rank_sub_expr(x, y):
    if callable(x): x = x()
    if callable(y): y = y()
    
    # 保持 Pandas Series 结构
    result = rank_sub(x.values, y.values, cross_dates)
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_absolute_expr(x):
    if callable(x): x = x()
    result = safe_absolute(x.values)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_sqrt_expr(x):
    if callable(x): x = x()
    result = safe_sqrt(x.values)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_inverse_expr(x):
    if callable(x): x = x()
    result = safe_inverse(x.values)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def safe_log_expr(x):
    if callable(x): x = x()
    result = safe_log(x.values)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def x_rank_expr(x):
    if callable(x): x = x()
    result = x_rank(x.values, cross_dates)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

def sigmoid_expr(x):
    if callable(x): x = x()
    result = sigmoid(x.values)  # 只传需要的参数
    return pd.Series(result, index=x.index).sort_index(level=['date', 'ticker'], sort_remaining=True)

# %%
class Expr: pass

TERMINALS =full_data_factors.columns.tolist()
terminal_dict = {name: full_data_factors[name] for name in TERMINALS}

pset = gp.PrimitiveSetTyped("MAIN", [], Expr)

# Updated context_wrapper
def context_wrapper(data, name):
    def wrapped(**kwargs):
        # print(f"Attempting to access: {name}")
        if name in data.columns:
            return data[name]  # Return the column data
        else:
            raise ValueError(f"Column '{name}' not found in the data.")
    wrapped.__name__ = name  # Ensure the callable has a unique name
    return wrapped
    
cross_tickers = full_data_factors.index.get_level_values('ticker').values.astype(np.int64)
cross_dates = full_data_factors.index.get_level_values('date').values.astype(np.int64)

full_data_factors_ts = full_data_factors.sort_index(level=['ticker', 'date'], sort_remaining=True)
ts_tickers = full_data_factors_ts.index.get_level_values('ticker').values.astype(np.int64)
ts_dates = full_data_factors_ts.index.get_level_values('date').values.astype(np.int64)

pset.context.update({"factor_columns": full_data_factors, "np": np, "random": random})
for name in TERMINALS:
    pset.addTerminal(context_wrapper(full_data_factors, name), Expr, name=name)

# ================================================= 测试成功 ===============================================#
"""
时序
"""
pset.addPrimitive(rolling_skew_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_mean_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_std_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_sum_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_max_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_min_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_kurt_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_prod_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_argmin_expr, [Expr, int], Expr) 
pset.addPrimitive(rolling_argmax_expr, [Expr, int], Expr) 
pset.addPrimitive(safe_delay_expr, [Expr, int], Expr) 
pset.addPrimitive(ts_zscore_expr, [Expr, int], Expr) 
pset.addPrimitive(ts_argmaxmin_expr, [Expr, int], Expr) 
pset.addPrimitive(safe_delta_expr, [Expr, int], Expr) 
pset.addPrimitive(ts_rank_expr, [Expr, int], Expr) 

pset.addPrimitive(ts_cov_expr, [Expr, Expr, int], Expr)
pset.addPrimitive(ts_corr_expr, [Expr, Expr, int], Expr)

"""
截面
"""
pset.addPrimitive(safe_absolute_expr, [Expr], Expr) 
pset.addPrimitive(safe_sqrt_expr, [Expr], Expr)
pset.addPrimitive(safe_inverse_expr, [Expr], Expr)
pset.addPrimitive(safe_log_expr, [Expr], Expr)
pset.addPrimitive(x_rank_expr, [Expr], Expr)
pset.addPrimitive(sigmoid_expr, [Expr], Expr)

pset.addPrimitive(rank_sub_expr, [Expr, Expr], Expr)
pset.addPrimitive(rank_div_expr, [Expr, Expr], Expr)

pset.addPrimitive(safe_add_expr, [Expr, Expr], Expr)
pset.addPrimitive(safe_sub_expr, [Expr, Expr], Expr)
pset.addPrimitive(safe_mul_expr, [Expr, Expr], Expr)
pset.addPrimitive(safe_div_expr, [Expr, Expr], Expr)

# ================================================= 测试成功 ===============================================#

# ================================================= 待测试 ===============================================#

# ================================================= 待测试 ===============================================#

def validate_expression(expr):
    terminals = [str(term) for term in expr]  # Convert terminals to string
    return len(terminals) == len(set(terminals))  # Return True if no duplicates

def generate_valid_expr(pset=pset, type_=Expr):  
    expr = gp.genHalfAndHalf(pset=pset, min_=1, max_=4, type_=type_)

    while not validate_expression(expr):
        expr = gp.genHalfAndHalf(pset=pset, min_=1, max_=4, type_=type_)

    return expr
    
def rand_window():
    return random.randint(2, 30)
pset.addEphemeralConstant("rand_window", rand_window, int)

def const_3() -> int: return 3 
def const_5() -> int: return 5
def const_10() -> int: return 10  
def const_20() -> int: return 20  
def const_60() -> int: return 60 

pset.addPrimitive(const_3, [], int)
pset.addPrimitive(const_5, [], int)
pset.addPrimitive(const_10, [], int)
pset.addPrimitive(const_20, [], int)
pset.addPrimitive(const_60, [], int)

# 注册工具箱
for name in ['FitnessMulti', 'Individual']:
    if hasattr(creator, name):
        delattr(creator, name)
        
'''Multi Fitnesses'''       
# creator.create("FitnessMulti", base.Fitness, weights=(1.0,1.0,))
# creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMulti)

'''Signle Fitness'''   
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("expr", generate_valid_expr)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
####### ICIR #########  
def cal_icir(factor_clean_rank, clean_target):

    # factor_rank_train = factor_values.unstack().rank(ascending=True, axis=1)
    IC = (factor_clean_rank.corrwith(clean_target, axis=1)).dropna()
    icir = IC.mean()/IC.std()
    return abs(icir)

####### Mutual Info #########    
def calc_mutual_info(factor_clean_rank, clean_target):
    aligned_factor, aligned_return = factor_clean_rank.align(clean_target, join='inner', axis=0)
    aligned_factor, aligned_return = aligned_factor.align(aligned_return, join='inner', axis=1)

    x = aligned_factor.values.flatten()
    y = aligned_return.values.flatten()
    
    mask = np.isfinite(x) & np.isfinite(y)
    x_clean = x[mask].reshape(-1, 1)
    y_clean = y[mask]

    mi = mutual_info_regression(x_clean, y_clean, discrete_features=False)
    return mi[0]

####### Turnover Mean ######### 
@njit
def calculate_turnover_long_mode(df_clean, top_pct=0.1):
    n_days, n_stocks = factor_values.shape
    turnover = np.zeros(n_days)

    prev_signal = np.zeros(n_stocks)

    for i in range(n_days):
        row = factor_values[i, :]
        valid_mask = ~np.isnan(row)
        valid_values = row[valid_mask]

        n_valid = valid_values.size
        if n_valid == 0:
            turnover[i] = 0.0
            continue

        n_top = max(1, int(n_valid * top_pct))

        # 排名：小的排前，取top n_top 个索引
        sorted_indices = np.argsort(valid_values)
        selected_indices = np.flatnonzero(valid_mask)[sorted_indices[:n_top]]

        # 构建当日信号
        signal = np.zeros(n_stocks)
        signal[selected_indices] = 1

        # 换手率 = 当日买卖信号变化数量 / 2
        turnover[i] = np.abs(signal - prev_signal).sum() / 2

        # 更新前一日信号
        prev_signal = signal

    turnover_mean = turnover.mean()
    return turnover_mean

@njit
def calculate_turnover_weight_mode(factor_values, n_range=10):
    n_days, n_stocks = factor_values.shape
    turnover_series = np.empty(n_days)
    turnover_series[:] = np.nan

    weight_all = np.zeros((n_days, n_stocks))

    for day in range(n_days):
        # 手动计算每行的最大值，忽略NaN
        row_max = np.nanmax(factor_values[day])

        if np.isnan(row_max):
            continue

        for layer in range(1, n_range+1):
            lower = (1/n_range) * (layer-1) * row_max
            upper = (1/n_range) * layer * row_max if layer < n_range else row_max + 1

            # mask layer
            mask = (factor_values[day] >= lower) & (factor_values[day] < upper)

            stock_count = np.sum(mask)
            if stock_count > 0:
                weight_all[day, mask] = 1.0 / stock_count

    # 换手率 = 权重变动绝对值之和
    turnover_series[1:] = np.sum(np.abs(weight_all[1:] - weight_all[:-1]), axis=1)

    return np.nanmean(turnover_series)

# %%
alpha = 0.005

def evaluateFitness(individual): #  train_data_set, train_clean_rank_target, val_data_set, val_clean_rank_target
    ###===== 生成公式及因子
    print(f"Compiled expression: {individual}")
    func = gp.compile(expr=individual, pset=pset)
    factor_values = func
    
    ###===== 对因子值做截面排序
    factor_values = factor_values.replace(0, np.nan).unstack().replace([np.inf, -np.inf], np.nan)
    df_clean = (factor_values * final_universe).dropna(how='all', axis=0)
    full_data_clean_rank_factor = df_clean.rank(ascending=True, axis=1, method='first')

    ###===== 加入complexity penalty
    # fitness = len(individual)
    # penalty = alpha * len(individual)
    
    ###===== 1. 验证集ICIR fitness
    val_clean_rank_factor = full_data_clean_rank_factor[(full_data_clean_rank_factor.index > '2021-06-30')]

    icir_val = cal_icir(val_clean_rank_factor, val_clean_rank_target)

    factor_array = df_clean.to_numpy(dtype=np.float64)
    to_mean_val = calculate_turnover_weight_mode(factor_array)
    
    fitness1 = to_mean_val
    fitness2 = icir_val
    fitness = icir_val/to_mean_val
    
    return (fitness,)
   
ind1 = toolbox.individual()
print (f"适应度\n：", evaluateFitness(ind1))
# Out:
# Compiled expression: rolling_kurt_expr(ts_rank_expr(rank_sub_expr(open, twap), const_60()), const_3())
# 适应度
# ： (0.2546448182748728,)

# %%
def eaMuPlusLambda_with_early_stopping(
    population, toolbox, mu, lambda_, cxpb, mutpb, ngen, 
    stats=None, halloffame=None, verbose=__debug__,
    patience=5, delta=1e-4):

    logbook = tools.Logbook()
    logbook.header = ['gen', 'nevals'] + (stats.fields if stats else [])

    best_fitness = -np.inf
    generations_no_improve = 0

    # 去重函数
    def deduplicate_population(pop):
        expr_set = set()
        unique_pop = []
        for ind in pop:
            expr_str = str(ind)
            if expr_str not in expr_set:
                expr_set.add(expr_str)
                unique_pop.append(ind)
        return unique_pop

    # 初始评估
    fitnesses = list(toolbox.map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    # 更新 HOF
    if halloffame is not None:
        halloffame.update(population)

    # 初始去重
    population = deduplicate_population(population)

    # 记录初代统计
    valid_population = [ind for ind in population if ind.fitness.valid]
    record = stats.compile(valid_population) if stats and len(valid_population) > 0 else {}
    logbook.record(gen=0, nevals=len(population), **record)
    if verbose:
        print(logbook.stream)

    # 主迭代
    for gen in range(1, ngen + 1):

        # 生成 offspring
        offspring = toolbox.select(population, lambda_)
        offspring = list(map(toolbox.clone, offspring))

        # 交叉
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if np.random.rand() < cxpb:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values

        # 变异
        for mutant in offspring:
            if np.random.rand() < mutpb:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # 评估 offspring 中的无效个体
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        for ind in invalid_ind:
            try:
                fit = toolbox.evaluate(ind)
                ind.fitness.values = fit
            except Exception as e:
                print(f"[Invalid Expression in Evolution] {str(ind)} | Error: {str(e)}")
                ind.fitness.values = (0.0, )

        # 合并选择下一代 population
        population[:] = toolbox.select(population + offspring, mu)

        # 去重
        population = deduplicate_population(population)

        # 更新 valid_population
        valid_population = [ind for ind in population if ind.fitness.valid]

        # 更新 HOF
        if halloffame is not None:
            try:
                halloffame.update(valid_population)
            except Exception as e:
                print(f"[HOF Update Error] {str(e)}")

        # 记录统计
        record = stats.compile(valid_population) if stats and len(valid_population) > 0 else {}
        logbook.record(gen=gen, nevals=len(invalid_ind), **record)
        if verbose:
            print(logbook.stream)

        # Early Stopping 检查
        if valid_population:
            current_best = max(ind.fitness.values[0] for ind in valid_population)
            if current_best - best_fitness > delta:
                best_fitness = current_best
                generations_no_improve = 0
            else:
                generations_no_improve += 1

            if generations_no_improve >= patience:
                print(f"Early stopping triggered at generation {gen}. No significant improvement in {patience} generations.")
                break

    return population, logbook
    
def initialize_population_with_screening(toolbox, n_population, fitness_threshold=0, length_threshold=10):
    raw_population = toolbox.population(n=3 * n_population)
    fitness_and_len = []

    for ind in raw_population:
        try:
            fit = toolbox.evaluate(ind)
            ind.fitness.values = fit
            expr_len = len(ind)
            fitness_and_len.append((ind, fit[0], expr_len))
        except Exception as e:
            print(f"[Invalid Expression in Init] {str(ind)} | Error: {str(e)}")
            ind.fitness.values = (0.0,)
            fitness_and_len.append((ind, 0.0, 999))  # 长度设大，保证筛掉

    filtered_population = [
        ind for ind, rot, length in fitness_and_len
        if (rot >= fitness_threshold and length <= length_threshold)
    ]

    print(f"筛选后剩余 {len(filtered_population)} 个个体")

    # if len(filtered_population) >= n_population:
    #     population = random.sample(filtered_population, n_population)
    # else:
    #     population = filtered_population.copy()
    #     while len(population) < n_population:
    #         new_ind = toolbox.individual()
    #         try:
    #             fit = toolbox.evaluate(new_ind)
    #             new_ind.fitness.values = fit
    #             if fit[0] >= fitness_threshold and fit[1] <= length_threshold:
    #                 population.append(new_ind)
    #         except Exception as e:
    #             print(f"[Invalid Expression in Refill] {str(new_ind)} | Error: {str(e)}")
    #             new_ind.fitness.values = (0.0,)

    # print(f"最终初始化种群数量: {len(population)}")
    return population


def evaluate_individual(ind):
    try:
        return evaluateFitness(ind)
    except Exception as e:
        print(f"[Invalid Individual] {str(ind)} | Error: {str(e)}")
        return (0.0,)

toolbox.register("evaluate", evaluate_individual)
toolbox.register("mate", gp.cxOnePointLeafBiased, termpb=0.2)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr, pset=pset)
toolbox.register("select", tools.selTournament, tournsize=20)

## 初始化种群
population = initialize_population_with_screening(toolbox, n_population=500, # 筛选初始化种群 informed init population
                                                  fitness_threshold=0, length_threshold=9) # ideal ：icir=2 turnovers=0.3 fitness = 2/0.3
hof = tools.HallOfFame(100, similar=np.array_equal)

stats_multi = tools.Statistics(lambda ind: ind.fitness.values)

stats_multi.register("ICIR/TO_avg", lambda values: np.mean([v[0] for v in values]))
stats_multi.register("ICIR/TO_max", lambda values: np.max([v[0] for v in values]))
stats_multi.register("ICI/TO_min", lambda values: np.min([v[0] for v in values]))

population, logbook = eaMuPlusLambda_with_early_stopping(
    population, toolbox,
    mu=200, lambda_=150,
    cxpb=0.4, mutpb=0.2,
    ngen=100,  
    stats=stats_multi,
    halloffame=hof,
    verbose=True,
    patience=10,  # 连续 10 代无明显提升就停
    delta=1e-4   # max fitness 改进小于 0.0001 判定为无明显提升
)
# Out:
# Compiled expression: rolling_sum_expr(vwap, 8)
# Compiled expression: safe_delta_expr(ts_corr_expr(sigmoid_expr(turnover_rate), rolling_min_expr(high, 16), const_60()), const_10())
# Compiled expression: safe_mul_expr(rolling_min_expr(low, 24), safe_inverse_expr(high))
# Compiled expression: rolling_std_expr(ts_argmaxmin_expr(rolling_sum_expr(vwap, 25), const_5()), 25)
# Compiled expression: rolling_prod_expr(volume, 28)
# Compiled expression: rolling_skew_expr(total_turnover, 3)
# Compiled expression: rolling_kurt_expr(rolling_prod_expr(rank_div_expr(rolling_std_expr(twap, 16), rolling_mean_expr(total_turnover, 20)), const_5()), const_10())
# Compiled expression: safe_sqrt_expr(ts_rank_expr(rolling_max_expr(adj_return, 23), const_20()))
# Compiled expression: rolling_mean_expr(ts_corr_expr(rolling_kurt_expr(high, 23), safe_add_expr(vwap, twap), const_20()), const_3())
# Compiled expression: rolling_min_expr(close, const_60())
# Compiled expression: safe_sub_expr(safe_inverse_expr(vwap), rolling_prod_expr(twap, 2))
# Compiled expression: sigmoid_expr(close)
# Compiled expression: safe_delay_expr(vwap, const_10())
# Compiled expression: rolling_sum_expr(safe_sqrt_expr(twap), const_10())
# Compiled expression: rolling_sum_expr(rank_div_expr(twap, turnover_rate), const_20())
# Compiled expression: x_rank_expr(rolling_kurt_expr(total_turnover, 5))
# Compiled expression: safe_mul_expr(safe_inverse_expr(safe_add_expr(adj_return, total_turnover)), rolling_skew_expr(safe_delta_expr(vwap, 11), const_10()))
# Compiled expression: rolling_skew_expr(safe_delay_expr(rolling_prod_expr(vwap, 5), const_3()), const_10())
# Compiled expression: rolling_skew_expr(close, 18)
# Compiled expression: rolling_kurt_expr(ts_argmaxmin_expr(safe_sqrt_expr(high), 11), const_3())
# Compiled expression: rolling_mean_expr(safe_sub_expr(volume, rolling_prod_expr(low, const_5())), const_10())
# Compiled expression: safe_log_expr(ts_corr_expr(low, close, 10))
# Compiled expression: rank_div_expr(rolling_argmax_expr(safe_delta_expr(rolling_skew_expr(adj_return, 15), const_20()), const_3()), rolling_max_expr(rolling_kurt_expr(rolling_mean_expr(low, 25), const_60()), const_5()))
# Compiled expression: safe_log_expr(ts_zscore_expr(rank_div_expr(rolling_kurt_expr(open, 3), safe_sub_expr(twap, high)), const_5()))
# Compiled expression: rolling_min_expr(safe_delta_expr(close, const_5()), 13)
# Compiled expression: safe_delay_expr(adj_return, const_3())
# Compiled expression: rolling_argmin_expr(safe_add_expr(safe_delta_expr(rolling_max_expr(vwap, 5), const_10()), close), 13)
# Compiled expression: rolling_skew_expr(rolling_kurt_expr(total_turnover, 14), const_60())
# Compiled expression: rolling_skew_expr(x_rank_expr(total_turnover), const_10())
# Compiled expression: ts_argmaxmin_expr(volume, 17)
# Compiled expression: safe_delay_expr(volume, const_10())
# Compiled expression: safe_inverse_expr(twap)
# Compiled expression: safe_delta_expr(open, const_3())
# Compiled expression: rolling_kurt_expr(turnover_rate, 12)
# Compiled expression: ts_rank_expr(total_turnover, 25)
# Compiled expression: safe_sqrt_expr(rank_sub_expr(volume, vwap))
# Compiled expression: rolling_max_expr(vwap, const_3())
# Compiled expression: rolling_min_expr(vwap, 20)
# Compiled expression: safe_sub_expr(open, total_turnover)
# Compiled expression: rolling_std_expr(rolling_prod_expr(rank_div_expr(high, twap), const_20()), const_5())
# Compiled expression: safe_delay_expr(safe_sqrt_expr(ts_zscore_expr(vwap, 29)), const_60())
# Compiled expression: rolling_max_expr(twap, 9)
# Compiled expression: ts_argmaxmin_expr(x_rank_expr(high), const_3())
# Compiled expression: rolling_max_expr(rolling_mean_expr(vwap, 12), const_60())
# Compiled expression: safe_delay_expr(low, 20)
# Compiled expression: rolling_argmin_expr(total_turnover, 11)
# Compiled expression: rolling_argmax_expr(safe_div_expr(volume, turnover_rate), const_60())
# Compiled expression: sigmoid_expr(vwap)
# Compiled expression: rolling_std_expr(ts_corr_expr(volume, open, 15), const_10())
# Compiled expression: safe_delay_expr(safe_log_expr(rolling_min_expr(rank_div_expr(volume, turnover_rate), const_5())), 29)
# Compiled expression: rank_sub_expr(open, adj_return)
# Compiled expression: safe_sqrt_expr(rolling_prod_expr(safe_log_expr(x_rank_expr(total_turnover)), 24))
# Compiled expression: sigmoid_expr(total_turnover)
# Compiled expression: rolling_mean_expr(rolling_argmin_expr(total_turnover, 6), const_5())
# Compiled expression: ts_corr_expr(safe_div_expr(rolling_max_expr(twap, 2), ts_argmaxmin_expr(high, 17)), safe_inverse_expr(rolling_prod_expr(turnover_rate, 14)), const_5())
# Compiled expression: rolling_argmin_expr(rolling_kurt_expr(ts_zscore_expr(safe_div_expr(high, adj_return), const_3()), 25), const_60())
# Compiled expression: safe_delta_expr(ts_argmaxmin_expr(ts_rank_expr(rolling_std_expr(volume, 11), const_3()), const_20()), const_60())
# Compiled expression: sigmoid_expr(open)
# Compiled expression: rolling_sum_expr(ts_corr_expr(vwap, volume, 25), const_60())
# Compiled expression: ts_argmaxmin_expr(safe_delay_expr(safe_add_expr(low, high), const_10()), const_20())
# Compiled expression: safe_sqrt_expr(turnover_rate)
# Compiled expression: rolling_kurt_expr(high, 16)
# Compiled expression: rolling_skew_expr(total_turnover, 11)
# Compiled expression: x_rank_expr(ts_argmaxmin_expr(rolling_std_expr(high, 5), const_10()))
# Compiled expression: safe_add_expr(safe_log_expr(rolling_sum_expr(turnover_rate, 18)), high)
# Compiled expression: safe_inverse_expr(rolling_skew_expr(turnover_rate, 9))
# Compiled expression: rank_div_expr(rolling_kurt_expr(high, 24), ts_argmaxmin_expr(volume, 14))
# Compiled expression: rolling_argmin_expr(sigmoid_expr(safe_log_expr(high)), const_5())
# Compiled expression: rolling_max_expr(turnover_rate, const_3())
# Compiled expression: rolling_std_expr(ts_cov_expr(rank_div_expr(rolling_max_expr(adj_return, 21), high), open, const_20()), const_3())
# Compiled expression: safe_sub_expr(safe_inverse_expr(rolling_sum_expr(total_turnover, 3)), safe_delay_expr(rank_div_expr(open, high), const_60()))
# Compiled expression: ts_zscore_expr(rolling_argmax_expr(volume, 28), const_3())
# Compiled expression: rolling_skew_expr(twap, 9)
# Compiled expression: rank_div_expr(vwap, turnover_rate)
# Compiled expression: sigmoid_expr(adj_return)
# Compiled expression: sigmoid_expr(open)
# Compiled expression: safe_div_expr(rank_div_expr(sigmoid_expr(close), rolling_std_expr(volume, 21)), rolling_skew_expr(safe_delay_expr(twap, 30), const_3()))
# Compiled expression: safe_add_expr(ts_rank_expr(rolling_min_expr(open, 9), const_20()), rank_sub_expr(rolling_std_expr(twap, 18), rolling_argmin_expr(low, 14)))
# Compiled expression: rolling_prod_expr(volume, 3)
# Compiled expression: sigmoid_expr(volume)
# Compiled expression: safe_delay_expr(volume, const_60())
# Compiled expression: rank_div_expr(rolling_std_expr(low, const_3()), ts_rank_expr(vwap, const_5()))
# Compiled expression: safe_delay_expr(rolling_argmax_expr(rank_div_expr(rolling_sum_expr(twap, 29), rolling_mean_expr(high, 21)), const_5()), const_10())
# Compiled expression: ts_argmaxmin_expr(safe_sub_expr(rolling_std_expr(vwap, 24), safe_log_expr(adj_return)), const_10())
# Compiled expression: safe_inverse_expr(twap)
# Compiled expression: rolling_std_expr(high, 7)
# Compiled expression: rolling_argmax_expr(rolling_argmin_expr(low, 9), const_60())
# Compiled expression: rolling_kurt_expr(safe_delay_expr(adj_return, 2), const_10())
# Compiled expression: ts_argmaxmin_expr(adj_return, 27)
# Compiled expression: ts_rank_expr(safe_div_expr(close, high), const_5())
# Compiled expression: safe_delta_expr(high, const_3())
# Compiled expression: rank_div_expr(close, adj_return)
# Compiled expression: safe_log_expr(low)
# Compiled expression: safe_sub_expr(safe_inverse_expr(rolling_max_expr(volume, 29)), rolling_min_expr(ts_rank_expr(adj_return, 25), const_10()))
# Compiled expression: safe_delay_expr(open, 26)
# Compiled expression: rolling_prod_expr(total_turnover, 27)
# Compiled expression: rolling_max_expr(rank_div_expr(safe_sqrt_expr(close), turnover_rate), const_3())
# Compiled expression: ts_argmaxmin_expr(rolling_std_expr(rolling_sum_expr(adj_return, 5), const_5()), const_10())
# Compiled expression: safe_absolute_expr(safe_delta_expr(adj_return, 3))
# Compiled expression: safe_log_expr(rank_div_expr(twap, high))
# Compiled expression: safe_inverse_expr(sigmoid_expr(turnover_rate))
# Compiled expression: safe_div_expr(volume, adj_return)
# Compiled expression: rank_div_expr(volume, vwap)
# Compiled expression: rolling_argmax_expr(total_turnover, 4)
# Compiled expression: rolling_min_expr(rolling_std_expr(sigmoid_expr(ts_zscore_expr(twap, 30)), const_10()), const_20())
# Compiled expression: rank_sub_expr(open, vwap)
# Compiled expression: rolling_max_expr(safe_delta_expr(safe_delay_expr(total_turnover, 28), const_3()), const_60())
# Compiled expression: safe_inverse_expr(safe_div_expr(high, close))
# Compiled expression: safe_mul_expr(rolling_kurt_expr(rolling_skew_expr(safe_add_expr(low, twap), const_3()), const_5()), rolling_argmax_expr(safe_sub_expr(rolling_std_expr(total_turnover, 12), x_rank_expr(adj_return)), const_10()))
# Compiled expression: safe_log_expr(twap)
# Compiled expression: rank_div_expr(ts_zscore_expr(close, 19), ts_rank_expr(high, 9))
# Compiled expression: rolling_argmin_expr(rolling_max_expr(ts_argmaxmin_expr(low, const_10()), 6), const_5())
# Compiled expression: safe_log_expr(ts_corr_expr(low, total_turnover, 27))
# Compiled expression: rolling_sum_expr(volume, 28)
# Compiled expression: rolling_argmin_expr(rolling_std_expr(total_turnover, 9), const_5())
# Compiled expression: rolling_sum_expr(turnover_rate, 15)
# Compiled expression: rolling_argmax_expr(close, 5)
# Compiled expression: ts_argmaxmin_expr(volume, 28)
# Compiled expression: sigmoid_expr(ts_zscore_expr(safe_delay_expr(rolling_argmax_expr(low, 7), 12), const_5()))
# Compiled expression: rank_div_expr(rolling_kurt_expr(vwap, 19), safe_delay_expr(close, 13))
# Compiled expression: rolling_mean_expr(safe_add_expr(close, turnover_rate), 16)
# Compiled expression: safe_absolute_expr(rolling_argmin_expr(safe_inverse_expr(total_turnover), const_3()))
# Compiled expression: safe_absolute_expr(twap)
# Compiled expression: rolling_skew_expr(ts_rank_expr(safe_log_expr(total_turnover), const_10()), const_3())
# Compiled expression: safe_sqrt_expr(safe_add_expr(turnover_rate, volume))
# Compiled expression: safe_inverse_expr(rolling_skew_expr(safe_div_expr(turnover_rate, rolling_argmin_expr(open, 16)), const_10()))
# Compiled expression: safe_div_expr(rolling_kurt_expr(rolling_min_expr(rolling_argmin_expr(total_turnover, 9), const_20()), const_5()), safe_sub_expr(safe_mul_expr(safe_delta_expr(high, 8), safe_delay_expr(low, 3)), rolling_max_expr(ts_rank_expr(close, 20), const_10())))
# Compiled expression: safe_div_expr(low, open)
# Compiled expression: safe_add_expr(rolling_min_expr(turnover_rate, 14), safe_sqrt_expr(volume))
# Compiled expression: safe_delta_expr(vwap, 20)
# Compiled expression: safe_delta_expr(adj_return, 20)
# Compiled expression: rolling_argmin_expr(rolling_std_expr(rolling_min_expr(rolling_kurt_expr(adj_return, 7), const_5()), const_10()), const_20())
# Compiled expression: safe_delta_expr(volume, const_5())
# Compiled expression: rolling_argmax_expr(vwap, 23)
# Compiled expression: rolling_prod_expr(rolling_std_expr(ts_cov_expr(turnover_rate, close, 6), const_10()), const_20())
# Compiled expression: rolling_argmin_expr(rolling_argmax_expr(safe_mul_expr(rank_div_expr(vwap, high), rolling_min_expr(low, 27)), const_20()), const_60())
# Compiled expression: safe_add_expr(low, adj_return)
# Compiled expression: rolling_mean_expr(safe_absolute_expr(high), const_60())
# Compiled expression: safe_sqrt_expr(rolling_sum_expr(safe_delay_expr(high, 6), const_10()))
# Compiled expression: rolling_max_expr(turnover_rate, const_20())
# Compiled expression: sigmoid_expr(x_rank_expr(safe_log_expr(volume)))
# Compiled expression: rolling_argmin_expr(rolling_skew_expr(rolling_argmax_expr(adj_return, 7), const_3()), 24)
# Compiled expression: safe_sub_expr(volume, low)
# Compiled expression: safe_sqrt_expr(safe_delay_expr(rolling_sum_expr(adj_return, 9), const_3()))
# Compiled expression: rank_sub_expr(ts_rank_expr(open, const_20()), rolling_min_expr(safe_add_expr(close, volume), const_5()))
# Compiled expression: safe_delta_expr(rolling_argmin_expr(safe_sub_expr(volume, low), const_60()), const_3())
# Compiled expression: safe_sqrt_expr(twap)
# Compiled expression: safe_add_expr(x_rank_expr(adj_return), rank_sub_expr(open, volume))
# Compiled expression: safe_absolute_expr(rolling_sum_expr(vwap, const_5()))
# Compiled expression: safe_div_expr(safe_sqrt_expr(safe_inverse_expr(adj_return)), rolling_mean_expr(ts_argmaxmin_expr(turnover_rate, 24), 28))
# Compiled expression: rolling_std_expr(high, 13)
# Compiled expression: rank_div_expr(x_rank_expr(volume), safe_div_expr(adj_return, low))
# Compiled expression: safe_delta_expr(safe_mul_expr(vwap, turnover_rate), const_5())
# Compiled expression: rolling_argmin_expr(safe_absolute_expr(safe_add_expr(rolling_std_expr(low, 25), safe_log_expr(twap))), const_5())
# Compiled expression: rolling_mean_expr(adj_return, 8)
# Compiled expression: rolling_sum_expr(vwap, const_10())
# Compiled expression: rolling_sum_expr(total_turnover, const_10())
# Compiled expression: rolling_kurt_expr(close, 4)
# Compiled expression: safe_inverse_expr(high)
# Compiled expression: rolling_prod_expr(total_turnover, 25)
# Compiled expression: rolling_prod_expr(twap, 6)
# Compiled expression: ts_argmaxmin_expr(volume, 26)
# Compiled expression: safe_delay_expr(open, 14)
# Compiled expression: safe_delta_expr(ts_corr_expr(twap, open, 23), const_5())
# Compiled expression: safe_log_expr(ts_argmaxmin_expr(adj_return, 5))
# Compiled expression: rolling_sum_expr(safe_sqrt_expr(total_turnover), const_5())
# Compiled expression: ts_corr_expr(volume, high, 11)
# Compiled expression: rolling_std_expr(low, 16)
# Compiled expression: rolling_min_expr(ts_corr_expr(vwap, safe_delta_expr(open, 22), const_20()), const_5())
# Compiled expression: rolling_prod_expr(twap, const_10())
# Compiled expression: ts_zscore_expr(low, const_5())
# Compiled expression: ts_corr_expr(rolling_max_expr(close, 3), rolling_min_expr(total_turnover, 16), const_3())
# Compiled expression: ts_rank_expr(safe_absolute_expr(rolling_std_expr(adj_return, 17)), const_20())
# Compiled expression: rolling_kurt_expr(vwap, const_20())
# Compiled expression: safe_inverse_expr(rolling_argmin_expr(safe_delta_expr(adj_return, 16), const_10()))
# Compiled expression: rolling_kurt_expr(ts_corr_expr(safe_add_expr(total_turnover, turnover_rate), volume, 25), const_5())
# Compiled expression: rolling_min_expr(ts_cov_expr(rank_sub_expr(rolling_kurt_expr(total_turnover, 25), rolling_max_expr(volume, 6)), safe_delay_expr(rolling_std_expr(close, 28), const_3()), const_10()), const_60())
# Compiled expression: rank_div_expr(close, total_turnover)
# Compiled expression: rolling_argmax_expr(safe_absolute_expr(safe_delay_expr(safe_log_expr(total_turnover), const_20())), const_5())
# Compiled expression: rolling_mean_expr(turnover_rate, 5)
# Compiled expression: x_rank_expr(turnover_rate)
# Compiled expression: safe_log_expr(sigmoid_expr(rolling_sum_expr(high, 27)))
# Compiled expression: safe_div_expr(rolling_argmax_expr(rolling_skew_expr(rolling_prod_expr(adj_return, 29), const_10()), const_20()), safe_log_expr(rolling_kurt_expr(safe_sub_expr(total_turnover, volume), const_3())))
# Compiled expression: safe_delta_expr(safe_inverse_expr(rank_div_expr(safe_delay_expr(adj_return, 23), sigmoid_expr(turnover_rate))), const_5())
# Compiled expression: safe_div_expr(turnover_rate, vwap)
# Compiled expression: rolling_argmax_expr(ts_corr_expr(volume, adj_return, 5), const_20())
# Compiled expression: rolling_argmax_expr(twap, 14)
# Compiled expression: rolling_std_expr(rolling_argmin_expr(twap, 12), const_20())
# Compiled expression: rolling_max_expr(rolling_std_expr(total_turnover, 22), 29)
# Compiled expression: safe_sub_expr(ts_cov_expr(volume, total_turnover, const_3()), adj_return)
# Compiled expression: ts_argmaxmin_expr(high, 25)
# Compiled expression: rolling_max_expr(safe_log_expr(vwap), const_20())
# Compiled expression: rolling_sum_expr(rolling_argmax_expr(rolling_argmin_expr(adj_return, 10), const_3()), const_20())
# Compiled expression: safe_sub_expr(safe_mul_expr(volume, low), ts_rank_expr(open, 22))
# Compiled expression: rolling_mean_expr(rolling_max_expr(low, const_20()), const_60())
# Compiled expression: ts_zscore_expr(safe_absolute_expr(adj_return), const_60())
# Compiled expression: rolling_kurt_expr(ts_argmaxmin_expr(safe_log_expr(low), const_60()), const_3())
# Compiled expression: rolling_sum_expr(safe_sub_expr(vwap, ts_rank_expr(high, 18)), const_60())
# Compiled expression: rolling_kurt_expr(vwap, const_5())
# Compiled expression: rank_div_expr(ts_zscore_expr(adj_return, 24), rolling_sum_expr(open, 2))
# Compiled expression: safe_absolute_expr(safe_delta_expr(turnover_rate, 9))
# Compiled expression: safe_div_expr(ts_argmaxmin_expr(vwap, 28), rolling_kurt_expr(adj_return, 2))
# Compiled expression: rolling_sum_expr(twap, 11)
# Compiled expression: safe_inverse_expr(open)
# Compiled expression: rolling_prod_expr(rolling_min_expr(rolling_argmin_expr(ts_corr_expr(close, total_turnover, 15), const_3()), const_60()), const_20())
# Compiled expression: ts_rank_expr(close, 19)
# Compiled expression: rank_sub_expr(rolling_min_expr(total_turnover, const_60()), twap)
# Compiled expression: rolling_min_expr(total_turnover, 6)
# Compiled expression: rolling_max_expr(safe_add_expr(ts_cov_expr(rank_div_expr(vwap, low), safe_delay_expr(volume, 28), const_10()), rolling_argmax_expr(rolling_kurt_expr(total_turnover, 26), const_3())), const_60())
# Compiled expression: safe_sqrt_expr(volume)
# Compiled expression: rolling_mean_expr(twap, 5)
# Compiled expression: safe_sqrt_expr(rolling_skew_expr(twap, 25))
# Compiled expression: safe_delta_expr(ts_rank_expr(open, 12), 20)
# Compiled expression: ts_argmaxmin_expr(turnover_rate, const_60())
# Compiled expression: rolling_argmin_expr(twap, 5)
# Compiled expression: safe_sqrt_expr(rolling_kurt_expr(safe_log_expr(safe_delta_expr(twap, 9)), 5))
# Compiled expression: rolling_sum_expr(close, 27)
# Compiled expression: safe_sqrt_expr(rank_div_expr(rolling_argmin_expr(rolling_argmax_expr(vwap, 16), const_3()), rolling_std_expr(ts_argmaxmin_expr(close, 27), const_60())))
# Compiled expression: safe_div_expr(close, high)
# Compiled expression: safe_delay_expr(ts_rank_expr(rolling_argmax_expr(rolling_prod_expr(adj_return, 7), const_5()), 6), const_60())
# Compiled expression: ts_argmaxmin_expr(safe_mul_expr(close, open), const_60())
# Compiled expression: safe_div_expr(volume, rolling_argmax_expr(turnover_rate, 28))
# Compiled expression: x_rank_expr(vwap)
# Compiled expression: ts_zscore_expr(rolling_min_expr(rank_div_expr(rolling_max_expr(vwap, 4), x_rank_expr(high)), 22), const_3())
# Compiled expression: rolling_argmin_expr(high, const_20())
# Compiled expression: safe_log_expr(safe_absolute_expr(rolling_mean_expr(ts_argmaxmin_expr(adj_return, 2), const_20())))
# Compiled expression: ts_zscore_expr(high, const_60())
# Compiled expression: ts_argmaxmin_expr(ts_zscore_expr(rolling_min_expr(safe_mul_expr(volume, adj_return), const_3()), const_5()), const_10())
# Compiled expression: ts_cov_expr(rolling_min_expr(twap, 22), rolling_prod_expr(high, 16), const_5())
# Compiled expression: safe_div_expr(ts_argmaxmin_expr(close, 9), adj_return)
# Compiled expression: ts_rank_expr(vwap, 25)
# Compiled expression: ts_rank_expr(vwap, 14)
# Compiled expression: safe_sub_expr(safe_delay_expr(rolling_argmin_expr(twap, 28), const_20()), ts_argmaxmin_expr(safe_delta_expr(volume, 7), const_10()))
# Compiled expression: rolling_mean_expr(total_turnover, const_3())
# Compiled expression: rolling_std_expr(ts_argmaxmin_expr(volume, 28), const_20())
# Compiled expression: sigmoid_expr(rank_div_expr(rolling_prod_expr(vwap, 13), ts_zscore_expr(total_turnover, 23)))
# Compiled expression: rolling_mean_expr(twap, const_3())
# Compiled expression: safe_delay_expr(ts_zscore_expr(rolling_std_expr(low, 15), const_60()), const_20())
# Compiled expression: rolling_std_expr(total_turnover, const_20())
# Compiled expression: rolling_max_expr(safe_delta_expr(safe_absolute_expr(ts_zscore_expr(low, 8)), const_3()), 17)
# Compiled expression: ts_rank_expr(low, const_10())
# Compiled expression: rolling_argmin_expr(x_rank_expr(adj_return), const_10())
# Compiled expression: rank_div_expr(high, low)
# Compiled expression: rolling_mean_expr(safe_mul_expr(turnover_rate, close), const_3())
# Compiled expression: safe_absolute_expr(rolling_skew_expr(vwap, 29))
# Compiled expression: safe_delta_expr(rolling_sum_expr(open, 10), const_60())
# Compiled expression: sigmoid_expr(safe_absolute_expr(x_rank_expr(rolling_argmax_expr(low, 2))))
# Compiled expression: ts_rank_expr(open, 5)
# Compiled expression: safe_delay_expr(vwap, 7)
# Compiled expression: safe_log_expr(safe_delta_expr(safe_add_expr(close, turnover_rate), const_60()))
# Compiled expression: ts_zscore_expr(twap, 30)
# Compiled expression: safe_add_expr(safe_inverse_expr(safe_log_expr(volume)), safe_delta_expr(rolling_std_expr(low, 12), const_60()))
# Compiled expression: rolling_prod_expr(safe_sqrt_expr(safe_sub_expr(total_turnover, twap)), const_20())
# Compiled expression: rolling_argmin_expr(close, 23)
# Compiled expression: safe_inverse_expr(sigmoid_expr(turnover_rate))
# Compiled expression: safe_sqrt_expr(ts_rank_expr(low, 23))
# Compiled expression: rolling_argmin_expr(safe_delta_expr(safe_sqrt_expr(twap), const_20()), const_5())
# Compiled expression: x_rank_expr(volume)
# Compiled expression: safe_mul_expr(low, rolling_max_expr(rank_sub_expr(close, adj_return), const_20()))
# Compiled expression: ts_argmaxmin_expr(turnover_rate, const_20())
# Compiled expression: safe_delay_expr(rolling_prod_expr(vwap, 10), const_10())
# Compiled expression: rolling_argmax_expr(high, 15)
# Compiled expression: ts_rank_expr(rolling_std_expr(sigmoid_expr(high), const_5()), const_60())
# Compiled expression: rolling_kurt_expr(ts_cov_expr(close, high, 30), const_20())
# Compiled expression: safe_mul_expr(total_turnover, adj_return)
# Compiled expression: rolling_argmin_expr(close, 19)
# Compiled expression: rolling_max_expr(twap, 26)
# Compiled expression: rolling_skew_expr(turnover_rate, 24)
# Compiled expression: rolling_max_expr(total_turnover, 21)
# Compiled expression: rolling_min_expr(safe_delta_expr(turnover_rate, 14), const_3())
# Compiled expression: rolling_std_expr(ts_rank_expr(turnover_rate, 9), const_10())
# Compiled expression: rank_div_expr(turnover_rate, close)
# Compiled expression: safe_log_expr(safe_delta_expr(safe_div_expr(adj_return, turnover_rate), const_20()))
# Compiled expression: ts_rank_expr(sigmoid_expr(close), const_10())
# Compiled expression: safe_absolute_expr(sigmoid_expr(ts_corr_expr(adj_return, vwap, 21)))
# Compiled expression: rolling_std_expr(safe_sqrt_expr(safe_log_expr(ts_corr_expr(twap, low, 23))), 9)
# Compiled expression: rolling_max_expr(safe_log_expr(high), const_3())
# Compiled expression: rolling_prod_expr(turnover_rate, 17)
# Compiled expression: ts_cov_expr(turnover_rate, total_turnover, 25)
# Compiled expression: rolling_min_expr(rolling_kurt_expr(rank_sub_expr(low, high), 19), const_10())
# Compiled expression: rolling_kurt_expr(safe_inverse_expr(rolling_min_expr(rank_sub_expr(volume, open), 26)), const_3())
# Compiled expression: rolling_max_expr(rolling_argmin_expr(adj_return, 20), const_20())
# Compiled expression: rolling_skew_expr(rolling_mean_expr(adj_return, 30), 15)
# Compiled expression: rolling_argmin_expr(safe_div_expr(turnover_rate, close), const_10())
# Compiled expression: rank_div_expr(ts_zscore_expr(safe_log_expr(volume), const_5()), rolling_argmin_expr(rolling_kurt_expr(adj_return, 26), 11))
# Compiled expression: rolling_std_expr(vwap, const_3())
# Compiled expression: ts_argmaxmin_expr(safe_delay_expr(safe_div_expr(high, close), const_10()), const_5())
# Compiled expression: rolling_sum_expr(rolling_skew_expr(low, 11), 16)
# Compiled expression: ts_zscore_expr(rolling_skew_expr(low, 21), const_3())
# Compiled expression: safe_delta_expr(rolling_kurt_expr(safe_div_expr(twap, close), const_3()), const_20())
# Compiled expression: ts_corr_expr(high, turnover_rate, 25)
# Compiled expression: safe_delay_expr(ts_cov_expr(x_rank_expr(total_turnover), rolling_max_expr(turnover_rate, 17), const_60()), const_10())
# Compiled expression: x_rank_expr(twap)
# Compiled expression: ts_rank_expr(low, 9)
# Compiled expression: safe_absolute_expr(rank_sub_expr(twap, low))
# Compiled expression: rolling_std_expr(safe_log_expr(open), const_20())
# Compiled expression: ts_rank_expr(rolling_kurt_expr(twap, 19), const_60())
# Compiled expression: rank_sub_expr(twap, vwap)
# Compiled expression: rank_sub_expr(ts_corr_expr(safe_absolute_expr(x_rank_expr(total_turnover)), rolling_argmax_expr(rolling_prod_expr(close, 17), const_60()), const_10()), rolling_mean_expr(safe_inverse_expr(safe_log_expr(high)), const_20()))
# Compiled expression: rolling_max_expr(safe_absolute_expr(rolling_std_expr(rolling_skew_expr(vwap, 6), const_3())), const_20())
# Compiled expression: x_rank_expr(adj_return)
# Compiled expression: sigmoid_expr(rolling_min_expr(vwap, 27))
# Compiled expression: safe_log_expr(rolling_min_expr(rolling_std_expr(ts_corr_expr(total_turnover, open, 15), const_10()), const_60()))
# Compiled expression: rank_sub_expr(adj_return, total_turnover)
# Compiled expression: safe_add_expr(rolling_mean_expr(vwap, 7), rolling_kurt_expr(open, 23))
# Compiled expression: safe_delay_expr(rolling_max_expr(close, 5), const_60())
# Compiled expression: safe_absolute_expr(rolling_argmin_expr(adj_return, 19))
# Compiled expression: rank_sub_expr(adj_return, volume)
# Compiled expression: rank_sub_expr(close, low)
# Compiled expression: safe_absolute_expr(total_turnover)
# Compiled expression: safe_mul_expr(rolling_std_expr(open, 29), safe_sub_expr(volume, low))
# Compiled expression: safe_sub_expr(ts_zscore_expr(vwap, 13), ts_rank_expr(turnover_rate, 25))
# Compiled expression: rolling_std_expr(high, 2)
# Compiled expression: safe_sqrt_expr(ts_rank_expr(safe_mul_expr(open, volume), const_5()))
# Compiled expression: rolling_argmax_expr(sigmoid_expr(rolling_argmin_expr(total_turnover, 25)), const_60())
# Compiled expression: safe_add_expr(rolling_min_expr(adj_return, 9), safe_absolute_expr(vwap))
# Compiled expression: rolling_min_expr(adj_return, const_10())
# Compiled expression: ts_argmaxmin_expr(x_rank_expr(safe_inverse_expr(high)), const_20())
# Compiled expression: rolling_argmax_expr(rolling_sum_expr(rolling_mean_expr(vwap, 29), const_5()), 20)
# Compiled expression: safe_delay_expr(ts_rank_expr(rolling_argmax_expr(rank_div_expr(low, close), const_60()), const_20()), const_3())
# Compiled expression: ts_rank_expr(vwap, 20)
# Compiled expression: rolling_prod_expr(safe_div_expr(safe_add_expr(rolling_max_expr(turnover_rate, 13), rolling_mean_expr(total_turnover, 11)), twap), const_3())
# Compiled expression: rolling_min_expr(adj_return, 26)
# Compiled expression: safe_sub_expr(high, close)
# Compiled expression: ts_corr_expr(rolling_min_expr(turnover_rate, 16), rolling_sum_expr(twap, 30), const_20())
# Compiled expression: safe_delta_expr(twap, 17)
# Compiled expression: safe_inverse_expr(rolling_min_expr(ts_zscore_expr(high, 22), const_20()))
# Compiled expression: safe_sub_expr(turnover_rate, open)
# Compiled expression: safe_inverse_expr(close)
# Compiled expression: safe_inverse_expr(rolling_mean_expr(rolling_argmax_expr(close, 18), const_3()))
# Compiled expression: rolling_sum_expr(safe_mul_expr(open, high), const_60())
# Compiled expression: ts_argmaxmin_expr(safe_delay_expr(rolling_prod_expr(rolling_mean_expr(volume, 24), const_10()), const_20()), const_60())
# Compiled expression: safe_absolute_expr(turnover_rate)
# Compiled expression: sigmoid_expr(ts_argmaxmin_expr(rank_div_expr(safe_div_expr(vwap, twap), safe_add_expr(close, adj_return)), const_5()))
# Compiled expression: rank_div_expr(rolling_kurt_expr(vwap, 9), high)
# Compiled expression: ts_zscore_expr(rolling_argmax_expr(low, 30), const_20())
# Compiled expression: x_rank_expr(ts_rank_expr(rolling_min_expr(vwap, 13), const_5()))
# Compiled expression: rank_sub_expr(x_rank_expr(turnover_rate), sigmoid_expr(volume))
# Compiled expression: rank_sub_expr(safe_add_expr(open, vwap), ts_corr_expr(close, volume, 10))
# Compiled expression: safe_inverse_expr(rolling_kurt_expr(total_turnover, 9))
# Compiled expression: rolling_argmin_expr(ts_argmaxmin_expr(volume, 19), const_3())
# Compiled expression: ts_zscore_expr(safe_delta_expr(safe_add_expr(safe_log_expr(adj_return), ts_argmaxmin_expr(turnover_rate, 29)), const_60()), const_20())
# Compiled expression: rolling_prod_expr(sigmoid_expr(adj_return), const_60())
# Compiled expression: safe_inverse_expr(close)
# Compiled expression: sigmoid_expr(ts_cov_expr(open, high, 21))
# Compiled expression: rolling_kurt_expr(rank_div_expr(low, open), const_3())
# Compiled expression: rolling_max_expr(safe_mul_expr(ts_corr_expr(adj_return, turnover_rate, 21), rolling_mean_expr(high, 16)), const_10())
# Compiled expression: ts_rank_expr(close, 19)
# Compiled expression: safe_delta_expr(volume, 27)
# Compiled expression: safe_sub_expr(rolling_std_expr(vwap, 14), rank_div_expr(close, turnover_rate))
# Compiled expression: safe_delay_expr(high, 20)
# Compiled expression: rolling_std_expr(twap, const_60())
# Compiled expression: rank_div_expr(close, total_turnover)
# Compiled expression: ts_zscore_expr(rank_sub_expr(ts_cov_expr(vwap, high, 23), ts_rank_expr(open, 22)), const_10())
# Compiled expression: ts_argmaxmin_expr(volume, 4)
# Compiled expression: safe_delta_expr(twap, 20)
# Compiled expression: rolling_mean_expr(total_turnover, 8)
# Compiled expression: safe_div_expr(rank_div_expr(ts_zscore_expr(rolling_argmax_expr(low, 20), const_5()), safe_delta_expr(safe_delay_expr(total_turnover, 12), const_20())), open)
# Compiled expression: safe_delay_expr(high, const_3())
# Compiled expression: rolling_sum_expr(rolling_kurt_expr(ts_zscore_expr(high, 25), const_3()), const_5())
# Compiled expression: rolling_argmin_expr(safe_mul_expr(turnover_rate, close), const_10())
# Compiled expression: safe_inverse_expr(total_turnover)
# Compiled expression: rank_div_expr(safe_inverse_expr(safe_mul_expr(volume, total_turnover)), safe_add_expr(rolling_max_expr(close, 30), safe_absolute_expr(low)))
# Compiled expression: rolling_mean_expr(rank_sub_expr(total_turnover, open), const_5())
# Compiled expression: rolling_sum_expr(rank_sub_expr(total_turnover, twap), const_10())
# Compiled expression: rolling_argmax_expr(safe_absolute_expr(close), const_5())
# Compiled expression: safe_sub_expr(twap, close)
# Compiled expression: rolling_argmin_expr(safe_inverse_expr(close), const_60())
# Compiled expression: safe_inverse_expr(close)
# Compiled expression: safe_log_expr(close)
# Compiled expression: safe_delay_expr(total_turnover, 10)
# Compiled expression: safe_delay_expr(adj_return, 19)
# Compiled expression: sigmoid_expr(safe_sub_expr(high, total_turnover))
# Compiled expression: safe_inverse_expr(sigmoid_expr(adj_return))
# Compiled expression: rolling_kurt_expr(high, 28)
# Compiled expression: ts_zscore_expr(sigmoid_expr(rolling_skew_expr(open, 7)), const_20())
# Compiled expression: safe_absolute_expr(safe_delta_expr(rolling_kurt_expr(low, 11), const_60()))
# Compiled expression: safe_mul_expr(close, turnover_rate)
# Compiled expression: rolling_min_expr(vwap, const_5())
# Compiled expression: ts_cov_expr(rolling_kurt_expr(rolling_argmax_expr(rolling_mean_expr(high, 19), const_3()), const_20()), safe_log_expr(safe_inverse_expr(safe_sqrt_expr(twap))), const_5())
# Compiled expression: rolling_min_expr(adj_return, const_3())
# Compiled expression: safe_sub_expr(close, adj_return)
# Compiled expression: safe_div_expr(rolling_skew_expr(safe_log_expr(twap), const_20()), safe_add_expr(rolling_argmax_expr(open, 3), rolling_min_expr(turnover_rate, 3)))
# Compiled expression: rolling_sum_expr(rolling_mean_expr(low, 5), const_5())
# Compiled expression: rolling_kurt_expr(rolling_max_expr(rolling_skew_expr(high, 29), const_5()), const_20())
# Compiled expression: sigmoid_expr(low)
# Compiled expression: rolling_min_expr(turnover_rate, 25)
# Compiled expression: ts_argmaxmin_expr(safe_absolute_expr(rolling_skew_expr(high, 15)), const_20())
# Compiled expression: ts_corr_expr(rolling_kurt_expr(safe_log_expr(low), const_5()), safe_delay_expr(rolling_argmin_expr(total_turnover, 27), const_3()), const_20())
# Compiled expression: rolling_mean_expr(safe_mul_expr(adj_return, open), const_20())
# Compiled expression: safe_sqrt_expr(volume)
# Compiled expression: rolling_max_expr(high, const_20())
# Compiled expression: rank_div_expr(open, vwap)
# Compiled expression: ts_argmaxmin_expr(open, 7)
# Compiled expression: rolling_skew_expr(safe_delta_expr(rolling_sum_expr(turnover_rate, 7), const_20()), const_60())
# Compiled expression: rolling_prod_expr(twap, const_10())
# Compiled expression: ts_zscore_expr(high, 14)
# Compiled expression: safe_mul_expr(safe_log_expr(vwap), ts_argmaxmin_expr(safe_delay_expr(total_turnover, 26), const_10()))
# Compiled expression: ts_argmaxmin_expr(rolling_mean_expr(rolling_min_expr(open, 20), const_3()), 29)
# Compiled expression: rolling_min_expr(turnover_rate, 8)
# Compiled expression: x_rank_expr(ts_argmaxmin_expr(rank_sub_expr(low, turnover_rate), const_5()))
# Compiled expression: rolling_mean_expr(safe_add_expr(volume, open), 28)
# Compiled expression: safe_inverse_expr(ts_zscore_expr(sigmoid_expr(turnover_rate), const_3()))
# Compiled expression: ts_corr_expr(safe_sqrt_expr(total_turnover), vwap, const_10())
# Compiled expression: ts_corr_expr(sigmoid_expr(close), rolling_prod_expr(volume, 5), const_3())
# Compiled expression: safe_sqrt_expr(ts_zscore_expr(low, const_60()))
# Compiled expression: rolling_min_expr(twap, 21)
# Compiled expression: rolling_mean_expr(rolling_argmin_expr(ts_corr_expr(adj_return, vwap, 6), 29), const_60())
# Compiled expression: rolling_argmin_expr(rolling_kurt_expr(twap, 3), const_60())
# Compiled expression: safe_inverse_expr(turnover_rate)
# Compiled expression: sigmoid_expr(high)
# Compiled expression: safe_div_expr(volume, rolling_prod_expr(close, 23))
# Compiled expression: safe_absolute_expr(safe_sqrt_expr(rolling_std_expr(open, 16)))
# Compiled expression: rolling_sum_expr(rolling_kurt_expr(safe_div_expr(adj_return, volume), const_5()), const_20())
# Compiled expression: safe_delta_expr(twap, 30)
# Compiled expression: ts_rank_expr(safe_sqrt_expr(safe_inverse_expr(close)), const_10())
# Compiled expression: safe_mul_expr(rolling_kurt_expr(vwap, 25), rolling_argmin_expr(turnover_rate, 28))
# Compiled expression: rank_div_expr(safe_sub_expr(ts_argmaxmin_expr(vwap, 14), total_turnover), x_rank_expr(rolling_sum_expr(high, 13)))
# Compiled expression: safe_delay_expr(rolling_sum_expr(adj_return, 12), const_10())
# Compiled expression: safe_mul_expr(safe_add_expr(x_rank_expr(volume), turnover_rate), safe_sqrt_expr(close))
# Compiled expression: rolling_skew_expr(safe_delta_expr(high, 17), const_60())
# Compiled expression: safe_inverse_expr(close)
# Compiled expression: safe_delay_expr(rolling_max_expr(low, 11), const_60())
# Compiled expression: ts_rank_expr(close, 10)
# Compiled expression: safe_add_expr(rolling_min_expr(rolling_skew_expr(twap, 18), const_10()), safe_absolute_expr(safe_delay_expr(total_turnover, 28)))
# Compiled expression: rolling_argmax_expr(volume, const_60())
# Compiled expression: rolling_prod_expr(total_turnover, 11)
# Compiled expression: rolling_std_expr(safe_add_expr(high, volume), const_20())
# Compiled expression: ts_zscore_expr(turnover_rate, 6)
# Compiled expression: rolling_std_expr(close, 24)
# Compiled expression: safe_sqrt_expr(safe_delay_expr(rolling_sum_expr(volume, 4), const_60()))
# Compiled expression: safe_absolute_expr(safe_delta_expr(safe_sqrt_expr(total_turnover), const_10()))
# Compiled expression: safe_add_expr(close, open)
# Compiled expression: rank_sub_expr(high, close)
# Compiled expression: safe_inverse_expr(high)
# Compiled expression: ts_corr_expr(turnover_rate, low, 7)
# Compiled expression: safe_absolute_expr(ts_corr_expr(safe_div_expr(volume, turnover_rate), ts_rank_expr(adj_return, 23), 21))
# Compiled expression: ts_rank_expr(rolling_prod_expr(open, 16), const_60())
# Compiled expression: rolling_skew_expr(adj_return, const_60())
# Compiled expression: rolling_sum_expr(open, 2)
# Compiled expression: safe_delta_expr(safe_absolute_expr(rolling_min_expr(high, 26)), const_20())
# Compiled expression: sigmoid_expr(open)
# Compiled expression: x_rank_expr(safe_delay_expr(close, 14))
# Compiled expression: safe_log_expr(turnover_rate)
# Compiled expression: rolling_min_expr(turnover_rate, 8)
# Compiled expression: ts_zscore_expr(safe_delta_expr(turnover_rate, 12), const_60())
# Compiled expression: rolling_prod_expr(high, 3)
# Compiled expression: ts_corr_expr(low, rolling_max_expr(adj_return, const_10()), const_20())
# Compiled expression: ts_zscore_expr(low, 22)
# Compiled expression: rolling_argmin_expr(rolling_skew_expr(open, 12), const_5())
# Compiled expression: rolling_argmax_expr(rolling_skew_expr(low, 14), const_60())
# Compiled expression: rolling_prod_expr(rolling_min_expr(volume, 26), 24)
# Compiled expression: safe_sqrt_expr(sigmoid_expr(close))
# Compiled expression: ts_argmaxmin_expr(rolling_mean_expr(total_turnover, const_3()), 14)
# Compiled expression: rolling_mean_expr(rolling_prod_expr(x_rank_expr(safe_div_expr(high, adj_return)), const_60()), const_5())
# Compiled expression: rolling_max_expr(ts_zscore_expr(rolling_argmax_expr(twap, 4), const_60()), const_3())
# Compiled expression: safe_log_expr(rolling_std_expr(twap, 12))
# Compiled expression: ts_cov_expr(rolling_kurt_expr(rank_sub_expr(rolling_mean_expr(volume, 20), high), const_3()), rolling_min_expr(adj_return, const_5()), const_60())
# Compiled expression: safe_delta_expr(safe_inverse_expr(high), const_60())
# Compiled expression: rolling_kurt_expr(rolling_argmin_expr(rolling_max_expr(turnover_rate, 7), 4), const_10())
# Compiled expression: rolling_std_expr(vwap, 5)
# Compiled expression: rolling_skew_expr(rolling_sum_expr(twap, 11), const_3())
# Compiled expression: ts_argmaxmin_expr(sigmoid_expr(twap), const_60())
# Compiled expression: safe_delta_expr(safe_mul_expr(rolling_argmax_expr(turnover_rate, 11), rolling_skew_expr(adj_return, 21)), const_20())
# Compiled expression: rolling_max_expr(ts_zscore_expr(close, 12), 15)
# Compiled expression: rolling_kurt_expr(turnover_rate, 27)
# Compiled expression: ts_argmaxmin_expr(safe_sub_expr(ts_zscore_expr(rolling_argmin_expr(volume, 14), const_20()), safe_mul_expr(rolling_argmax_expr(turnover_rate, 18), x_rank_expr(total_turnover))), const_3())
# Compiled expression: safe_log_expr(safe_absolute_expr(rolling_std_expr(ts_zscore_expr(open, 29), const_3())))
# Compiled expression: rolling_std_expr(low, 3)
# Compiled expression: safe_mul_expr(rolling_argmax_expr(volume, 20), rolling_skew_expr(open, 9))
# Compiled expression: sigmoid_expr(twap)
# Compiled expression: rolling_argmin_expr(adj_return, 30)
# Compiled expression: rolling_argmax_expr(twap, 10)
# Compiled expression: rolling_std_expr(safe_div_expr(vwap, open), const_10())
# Compiled expression: rolling_kurt_expr(adj_return, 30)
# Compiled expression: sigmoid_expr(adj_return)
# Compiled expression: safe_sqrt_expr(rolling_mean_expr(turnover_rate, 11))
# Compiled expression: rolling_skew_expr(safe_add_expr(rank_sub_expr(close, safe_inverse_expr(low)), high), 12)
# Compiled expression: rolling_argmax_expr(rolling_mean_expr(open, 19), const_20())
# Compiled expression: rolling_sum_expr(volume, 16)
# Compiled expression: ts_rank_expr(adj_return, 3)
# Compiled expression: safe_add_expr(rolling_max_expr(ts_argmaxmin_expr(high, 12), const_60()), adj_return)
# Compiled expression: rolling_mean_expr(adj_return, 23)
# Compiled expression: safe_delta_expr(vwap, 9)
# Compiled expression: rolling_max_expr(safe_mul_expr(vwap, close), const_3())
# Compiled expression: rank_div_expr(rolling_max_expr(turnover_rate, 27), safe_sub_expr(adj_return, total_turnover))
# Compiled expression: rolling_sum_expr(high, 27)
# Compiled expression: safe_inverse_expr(adj_return)
# Compiled expression: safe_mul_expr(close, rolling_kurt_expr(turnover_rate, const_60()))
# Compiled expression: rolling_max_expr(total_turnover, 28)
# Compiled expression: rolling_std_expr(sigmoid_expr(ts_rank_expr(twap, 25)), const_20())
# Compiled expression: x_rank_expr(safe_absolute_expr(sigmoid_expr(adj_return)))
# Compiled expression: safe_sub_expr(rolling_prod_expr(close, 8), rolling_sum_expr(open, 19))
# Compiled expression: safe_delay_expr(ts_cov_expr(low, open, 12), 16)
# Compiled expression: rolling_argmin_expr(rolling_sum_expr(low, 26), const_3())
# Compiled expression: safe_log_expr(close)
# Compiled expression: ts_rank_expr(close, 10)
# Compiled expression: safe_div_expr(total_turnover, vwap)
# Compiled expression: sigmoid_expr(high)
# Compiled expression: x_rank_expr(high)
# Compiled expression: safe_inverse_expr(volume)
# Compiled expression: rolling_min_expr(rolling_skew_expr(safe_add_expr(ts_corr_expr(turnover_rate, low, 25), rolling_argmax_expr(high, 23)), const_60()), const_20())
# Compiled expression: safe_inverse_expr(rolling_kurt_expr(x_rank_expr(turnover_rate), const_5()))
# Compiled expression: rolling_mean_expr(safe_mul_expr(adj_return, high), const_20())
# Compiled expression: ts_argmaxmin_expr(rolling_skew_expr(volume, 5), const_3())
# Compiled expression: safe_sub_expr(rolling_std_expr(safe_delay_expr(high, 13), const_5()), safe_mul_expr(x_rank_expr(open), close))
# Compiled expression: ts_corr_expr(high, rolling_argmax_expr(safe_absolute_expr(close), const_60()), const_10())
# Compiled expression: ts_cov_expr(adj_return, safe_absolute_expr(open), const_20())
# Compiled expression: ts_rank_expr(twap, 7)
# Compiled expression: rolling_argmin_expr(x_rank_expr(adj_return), const_5())
# Compiled expression: ts_rank_expr(rolling_prod_expr(close, 28), const_10())
# Compiled expression: rolling_mean_expr(high, 28)
# Compiled expression: rank_sub_expr(high, low)
# Compiled expression: rolling_max_expr(vwap, 22)
# Compiled expression: safe_delta_expr(turnover_rate, 22)
# Compiled expression: rank_div_expr(ts_cov_expr(vwap, turnover_rate, 25), rolling_argmax_expr(adj_return, 16))
# Compiled expression: safe_sqrt_expr(ts_rank_expr(rolling_skew_expr(low, 10), const_20()))
# Compiled expression: safe_div_expr(adj_return, low)
# Compiled expression: safe_add_expr(rolling_mean_expr(safe_sqrt_expr(low), const_60()), total_turnover)
# Compiled expression: safe_delta_expr(turnover_rate, 29)
# Compiled expression: rank_div_expr(rolling_skew_expr(safe_delay_expr(open, 13), 15), safe_add_expr(rolling_std_expr(close, 8), vwap))
# Compiled expression: sigmoid_expr(high)
# Compiled expression: ts_zscore_expr(rolling_min_expr(twap, 8), const_3())
# Compiled expression: ts_argmaxmin_expr(rank_sub_expr(rolling_sum_expr(open, 4), safe_sqrt_expr(turnover_rate)), const_10())
# Compiled expression: safe_sqrt_expr(rolling_mean_expr(volume, const_5()))
# Compiled expression: rolling_kurt_expr(turnover_rate, 30)
# Compiled expression: rolling_max_expr(open, 2)
# Compiled expression: safe_log_expr(total_turnover)
# Compiled expression: rolling_mean_expr(twap, 16)
# Compiled expression: safe_sqrt_expr(volume)
# Compiled expression: rolling_prod_expr(sigmoid_expr(ts_zscore_expr(vwap, 15)), const_20())
# Compiled expression: rolling_prod_expr(safe_mul_expr(ts_zscore_expr(turnover_rate, 7), safe_sqrt_expr(open)), const_10())
# Compiled expression: safe_delay_expr(safe_absolute_expr(turnover_rate), const_5())
# Compiled expression: safe_div_expr(close, turnover_rate)
# Compiled expression: sigmoid_expr(twap)
# Compiled expression: rolling_skew_expr(twap, 22)
# Compiled expression: rank_div_expr(adj_return, low)
# Compiled expression: safe_add_expr(rolling_prod_expr(volume, 4), ts_rank_expr(vwap, 14))
# Compiled expression: ts_zscore_expr(adj_return, 27)
# Compiled expression: rolling_kurt_expr(twap, 7)
# Compiled expression: rolling_min_expr(safe_delta_expr(safe_mul_expr(sigmoid_expr(close), adj_return), 15), const_10())
# Compiled expression: ts_zscore_expr(twap, const_10())
# Compiled expression: rolling_std_expr(sigmoid_expr(low), 30)
# Compiled expression: ts_cov_expr(rolling_kurt_expr(safe_add_expr(open, high), const_3()), rolling_min_expr(low, 19), const_5())
# Compiled expression: rolling_argmin_expr(volume, const_60())
# Compiled expression: rolling_argmax_expr(close, 23)
# Compiled expression: safe_sub_expr(open, turnover_rate)
# Compiled expression: x_rank_expr(rolling_mean_expr(rolling_skew_expr(rolling_argmin_expr(twap, 12), const_5()), const_60()))
# Compiled expression: rolling_skew_expr(turnover_rate, 8)
# Compiled expression: ts_cov_expr(ts_argmaxmin_expr(turnover_rate, 20), safe_log_expr(close), const_60())
# Compiled expression: safe_sub_expr(safe_div_expr(volume, adj_return), safe_inverse_expr(high))
# Compiled expression: safe_mul_expr(safe_delta_expr(safe_delay_expr(rolling_std_expr(volume, 24), const_5()), const_3()), rolling_max_expr(sigmoid_expr(safe_add_expr(high, turnover_rate)), const_20()))
# Compiled expression: rolling_argmax_expr(volume, const_20())
# Compiled expression: rolling_mean_expr(rolling_argmax_expr(safe_log_expr(open), 30), const_60())
# Compiled expression: rank_div_expr(vwap, adj_return)
# Compiled expression: rank_sub_expr(x_rank_expr(twap), vwap)
# Compiled expression: rolling_skew_expr(rolling_sum_expr(rolling_argmax_expr(ts_rank_expr(open, 18), const_20()), const_10()), const_60())
# Compiled expression: rolling_kurt_expr(rolling_argmax_expr(low, 27), const_10())
# Compiled expression: rank_sub_expr(rolling_sum_expr(turnover_rate, const_20()), low)
# Compiled expression: safe_absolute_expr(ts_rank_expr(ts_argmaxmin_expr(rank_sub_expr(close, open), const_20()), const_5()))
# Compiled expression: x_rank_expr(safe_log_expr(turnover_rate))
# Compiled expression: rolling_argmax_expr(ts_zscore_expr(close, 8), const_10())
# Compiled expression: safe_mul_expr(safe_sub_expr(safe_delta_expr(adj_return, 29), ts_rank_expr(low, 10)), safe_sqrt_expr(rolling_kurt_expr(close, 23)))
# Compiled expression: safe_inverse_expr(ts_cov_expr(rolling_min_expr(high, 28), ts_rank_expr(volume, 9), const_10()))
# Compiled expression: rolling_min_expr(ts_argmaxmin_expr(safe_sqrt_expr(turnover_rate), const_60()), const_20())
# Compiled expression: rolling_argmax_expr(low, 7)
# Compiled expression: rolling_kurt_expr(volume, 22)
# Compiled expression: safe_delay_expr(rolling_kurt_expr(rolling_min_expr(total_turnover, 16), const_20()), const_10())
# Compiled expression: ts_corr_expr(rolling_argmax_expr(vwap, 28), rolling_prod_expr(total_turnover, 10), 7)
# Compiled expression: x_rank_expr(rolling_mean_expr(safe_div_expr(low, high), const_5()))
# Compiled expression: safe_inverse_expr(rolling_kurt_expr(open, 28))
# Compiled expression: rolling_argmax_expr(twap, 20)
# Compiled expression: safe_mul_expr(volume, high)
# Compiled expression: safe_delta_expr(rank_div_expr(sigmoid_expr(high), safe_inverse_expr(volume)), const_5())
# Compiled expression: rolling_mean_expr(twap, 12)
# Compiled expression: ts_corr_expr(open, adj_return, 28)
# Compiled expression: rolling_max_expr(close, 6)
# Compiled expression: rolling_mean_expr(rolling_argmin_expr(total_turnover, 30), const_20())
# Compiled expression: safe_inverse_expr(adj_return)
# Compiled expression: safe_log_expr(safe_sub_expr(vwap, adj_return))
# Compiled expression: rolling_prod_expr(high, 4)
# Compiled expression: rolling_skew_expr(total_turnover, 10)
# Compiled expression: ts_zscore_expr(close, 26)
# Compiled expression: safe_inverse_expr(rank_div_expr(turnover_rate, ts_argmaxmin_expr(safe_sub_expr(twap, high), const_10())))
# Compiled expression: rolling_prod_expr(total_turnover, 9)
# Compiled expression: rank_div_expr(rolling_max_expr(twap, 13), sigmoid_expr(open))
# Compiled expression: ts_argmaxmin_expr(ts_cov_expr(rolling_kurt_expr(safe_add_expr(adj_return, close), const_60()), sigmoid_expr(x_rank_expr(turnover_rate)), const_20()), const_3())
# Compiled expression: x_rank_expr(open)
# Compiled expression: rolling_min_expr(x_rank_expr(total_turnover), 4)
# Compiled expression: safe_inverse_expr(open)
# Compiled expression: x_rank_expr(safe_delta_expr(open, 9))
# Compiled expression: safe_delay_expr(turnover_rate, 29)
# Compiled expression: rolling_prod_expr(ts_cov_expr(close, volume, 26), const_60())
# ...
# Compiled expression: safe_add_expr(turnover_rate, high)
# Compiled expression: sigmoid_expr(twap)
# Compiled expression: safe_div_expr(rolling_argmax_expr(safe_log_expr(ts_corr_expr(open, twap, 2)), const_10()), rolling_skew_expr(adj_return, const_60()))
# Compiled expression: rolling_skew_expr(ts_zscore_expr(rolling_std_expr(turnover_rate, const_20()), 30), const_5())
# Compiled expression: rolling_max_expr(low, 13)
# Compiled expression: safe_sqrt_expr(twap)
# Compiled expression: ts_cov_expr(safe_sqrt_expr(high), rank_sub_expr(ts_argmaxmin_expr(adj_return, const_3()), vwap), 29)
# Compiled expression: rolling_std_expr(ts_cov_expr(volume, adj_return, 5), const_3())
# Compiled expression: safe_add_expr(vwap, twap)
# Compiled expression: ts_zscore_expr(turnover_rate, 27)
# Compiled expression: rolling_skew_expr(adj_return, const_5())
# Compiled expression: safe_delay_expr(safe_sqrt_expr(rolling_std_expr(ts_cov_expr(low, open, 7), 3)), const_20())
# Compiled expression: rolling_argmin_expr(rolling_mean_expr(safe_absolute_expr(ts_rank_expr(vwap, 30)), const_3()), 13)
# Compiled expression: safe_absolute_expr(rank_div_expr(safe_delta_expr(sigmoid_expr(high), const_5()), total_turnover))
# Compiled expression: rolling_mean_expr(rolling_prod_expr(adj_return, const_20()), 29)
# Compiled expression: safe_inverse_expr(rank_div_expr(safe_delay_expr(rolling_kurt_expr(high, 30), const_5()), sigmoid_expr(rolling_argmin_expr(close, 15))))
# Compiled expression: safe_log_expr(open)
# Compiled expression: safe_delay_expr(safe_inverse_expr(high), 9)
# Compiled expression: ts_zscore_expr(safe_add_expr(volume, vwap), const_3())
# Compiled expression: safe_log_expr(safe_inverse_expr(rolling_std_expr(ts_zscore_expr(low, 23), const_3())))
# Compiled expression: ts_rank_expr(rank_sub_expr(low, x_rank_expr(total_turnover)), const_10())
# Compiled expression: sigmoid_expr(rank_sub_expr(ts_rank_expr(vwap, 4), safe_absolute_expr(close)))
# Compiled expression: safe_sub_expr(safe_add_expr(open, ts_rank_expr(rolling_mean_expr(twap, 26), const_20())), volume)
# Compiled expression: ts_argmaxmin_expr(close, 14)
# Compiled expression: ts_rank_expr(adj_return, 18)
# Compiled expression: safe_delta_expr(x_rank_expr(rolling_mean_expr(safe_inverse_expr(adj_return), const_20())), const_5())
# Compiled expression: x_rank_expr(rolling_kurt_expr(vwap, 10))
# Compiled expression: ts_zscore_expr(open, 26)
# Compiled expression: rank_sub_expr(rolling_sum_expr(close, 12), x_rank_expr(high))
# Compiled expression: ts_rank_expr(adj_return, 20)
# Compiled expression: safe_add_expr(rolling_kurt_expr(adj_return, 3), safe_delay_expr(low, 7))
# Compiled expression: safe_sqrt_expr(low)
# Compiled expression: ts_rank_expr(low, 29)
# Compiled expression: ts_cov_expr(ts_argmaxmin_expr(rolling_argmin_expr(close, 12), const_20()), rolling_skew_expr(open, const_60()), const_5())
# Compiled expression: rolling_max_expr(twap, 29)
# Compiled expression: ts_zscore_expr(low, 25)
# Compiled expression: ts_cov_expr(total_turnover, close, 14)
# Compiled expression: sigmoid_expr(low)
# Compiled expression: safe_div_expr(safe_add_expr(safe_delay_expr(safe_sub_expr(close, high), const_20()), safe_inverse_expr(sigmoid_expr(low))), safe_log_expr(rolling_kurt_expr(x_rank_expr(open), const_3())))
# Compiled expression: rolling_mean_expr(safe_absolute_expr(high), const_20())
# Compiled expression: safe_log_expr(rolling_sum_expr(rolling_prod_expr(safe_absolute_expr(turnover_rate), const_20()), const_3()))
# Compiled expression: safe_inverse_expr(rolling_kurt_expr(x_rank_expr(adj_return), const_60()))
# Compiled expression: rolling_sum_expr(rolling_max_expr(close, 3), 30)
# Compiled expression: rank_div_expr(total_turnover, low)
# Compiled expression: rolling_mean_expr(safe_delta_expr(close, 21), const_60())
# Compiled expression: ts_cov_expr(low, open, 9)
# Compiled expression: safe_delta_expr(rolling_min_expr(high, const_10()), const_5())
# Compiled expression: safe_delay_expr(rank_div_expr(total_turnover, vwap), const_20())
# Compiled expression: ts_argmaxmin_expr(rolling_mean_expr(safe_delta_expr(rolling_min_expr(adj_return, 8), const_60()), const_10()), const_20())
# Compiled expression: safe_sqrt_expr(twap)
# Compiled expression: rank_sub_expr(x_rank_expr(rolling_max_expr(twap, 23)), ts_cov_expr(safe_sqrt_expr(low), ts_argmaxmin_expr(high, 24), const_5()))
# Compiled expression: rolling_max_expr(total_turnover, 14)
# Compiled expression: safe_sqrt_expr(open)
# Compiled expression: rolling_sum_expr(adj_return, 20)
# Compiled expression: rolling_skew_expr(low, 2)
# Compiled expression: rolling_argmin_expr(safe_inverse_expr(vwap), const_10())
# Compiled expression: safe_sqrt_expr(rolling_prod_expr(open, const_20()))
# Compiled expression: safe_add_expr(rolling_std_expr(vwap, 22), rolling_mean_expr(close, 12))
# Compiled expression: rolling_argmax_expr(adj_return, const_3())
# Compiled expression: rank_div_expr(close, open)
# Compiled expression: rolling_argmax_expr(safe_delta_expr(rolling_prod_expr(vwap, 6), const_60()), 30)
# Compiled expression: x_rank_expr(low)
# Compiled expression: safe_delta_expr(adj_return, const_5())
# Compiled expression: safe_add_expr(ts_zscore_expr(rolling_argmax_expr(close, 17), const_5()), rank_sub_expr(rolling_min_expr(volume, 17), rolling_mean_expr(adj_return, 27)))
# Compiled expression: rolling_max_expr(safe_inverse_expr(rolling_sum_expr(high, 12)), const_60())
# Compiled expression: rolling_prod_expr(sigmoid_expr(vwap), const_5())
# Compiled expression: safe_sub_expr(volume, high)
# Compiled expression: rolling_min_expr(twap, 18)
# Compiled expression: rolling_std_expr(x_rank_expr(low), const_60())
# Compiled expression: rolling_min_expr(close, 22)
# Compiled expression: rank_div_expr(ts_corr_expr(total_turnover, close, 29), rolling_max_expr(volume, 10))
# Compiled expression: safe_inverse_expr(high)
# Compiled expression: rolling_max_expr(adj_return, 25)
# Compiled expression: ts_argmaxmin_expr(rolling_mean_expr(adj_return, 28), 26)
# Compiled expression: safe_mul_expr(twap, close)
# Compiled expression: safe_add_expr(adj_return, twap)
# Compiled expression: safe_sub_expr(rolling_std_expr(vwap, 29), ts_rank_expr(twap, 13))
# Compiled expression: ts_rank_expr(open, const_10())
# Compiled expression: rolling_sum_expr(volume, 3)
# Compiled expression: rolling_sum_expr(safe_div_expr(open, high), const_5())
# Compiled expression: safe_mul_expr(rolling_std_expr(open, 3), rolling_skew_expr(vwap, 23))
# Compiled expression: safe_absolute_expr(safe_mul_expr(adj_return, vwap))
# Compiled expression: ts_corr_expr(low, volume, 29)
# Compiled expression: rolling_std_expr(ts_cov_expr(ts_argmaxmin_expr(total_turnover, 12), low, 11), const_5())
# Compiled expression: rolling_std_expr(safe_absolute_expr(rolling_max_expr(volume, 4)), const_60())
# Compiled expression: safe_absolute_expr(low)
# Compiled expression: ts_corr_expr(twap, vwap, 11)
# Compiled expression: rolling_min_expr(rolling_std_expr(turnover_rate, 27), const_10())
# Compiled expression: ts_argmaxmin_expr(rolling_skew_expr(x_rank_expr(rolling_prod_expr(adj_return, 22)), const_60()), 12)
# Compiled expression: rolling_prod_expr(rolling_sum_expr(rolling_min_expr(total_turnover, 29), const_20()), const_60())
# Compiled expression: rank_div_expr(rolling_argmax_expr(turnover_rate, 2), ts_cov_expr(adj_return, open, 12))
# Compiled expression: safe_mul_expr(rolling_kurt_expr(vwap, 6), ts_cov_expr(volume, total_turnover, 26))
# Compiled expression: safe_sqrt_expr(ts_rank_expr(volume, 20))
# Compiled expression: safe_sqrt_expr(rolling_argmax_expr(vwap, 27))
# Compiled expression: rolling_kurt_expr(volume, const_60())
# Compiled expression: safe_delay_expr(rolling_argmin_expr(ts_corr_expr(vwap, adj_return, 23), const_60()), const_20())
# Compiled expression: ts_zscore_expr(safe_mul_expr(twap, rolling_prod_expr(close, const_60())), const_5())
# Compiled expression: ts_cov_expr(vwap, volume, 11)
# Compiled expression: ts_rank_expr(safe_mul_expr(rolling_argmax_expr(vwap, 18), ts_argmaxmin_expr(turnover_rate, 7)), const_20())
# Compiled expression: x_rank_expr(safe_absolute_expr(high))
# Compiled expression: rolling_min_expr(open, 18)
# Compiled expression: safe_div_expr(rolling_mean_expr(turnover_rate, 29), ts_cov_expr(low, twap, 5))
# Compiled expression: rank_sub_expr(high, turnover_rate)
# Compiled expression: rolling_std_expr(rank_div_expr(safe_div_expr(close, adj_return), ts_zscore_expr(turnover_rate, 16)), 5)
# Compiled expression: rolling_argmax_expr(total_turnover, 11)
# Compiled expression: safe_mul_expr(ts_zscore_expr(x_rank_expr(rolling_skew_expr(high, 16)), const_20()), vwap)
# Compiled expression: rolling_kurt_expr(close, const_5())
# Compiled expression: safe_mul_expr(safe_delta_expr(rolling_std_expr(total_turnover, 12), const_20()), rolling_argmax_expr(safe_add_expr(twap, vwap), const_5()))
# Compiled expression: rolling_skew_expr(rolling_kurt_expr(ts_rank_expr(safe_sub_expr(vwap, adj_return), const_10()), const_3()), const_60())
# Compiled expression: safe_sub_expr(low, ts_corr_expr(safe_mul_expr(volume, twap), rolling_argmin_expr(turnover_rate, 25), 3))
# Compiled expression: x_rank_expr(rolling_min_expr(safe_delta_expr(safe_sub_expr(adj_return, turnover_rate), 15), const_3()))
# Compiled expression: rolling_skew_expr(vwap, const_10())
# Compiled expression: ts_zscore_expr(ts_argmaxmin_expr(rolling_kurt_expr(twap, 18), 17), const_10())
# Compiled expression: rolling_prod_expr(safe_sub_expr(open, twap), const_20())
# Compiled expression: rolling_kurt_expr(sigmoid_expr(turnover_rate), const_60())
# Compiled expression: rolling_std_expr(safe_sqrt_expr(safe_absolute_expr(low)), 27)
# Compiled expression: rolling_prod_expr(x_rank_expr(rank_div_expr(rolling_max_expr(volume, 16), safe_absolute_expr(vwap))), const_20())
# Compiled expression: rolling_skew_expr(rolling_prod_expr(safe_inverse_expr(twap), const_5()), const_10())
# Compiled expression: ts_argmaxmin_expr(safe_div_expr(low, volume), const_20())
# Compiled expression: ts_cov_expr(total_turnover, rolling_argmin_expr(twap, const_5()), const_10())
# Compiled expression: rolling_mean_expr(rolling_min_expr(rolling_skew_expr(turnover_rate, 21), const_3()), const_10())
# Compiled expression: safe_absolute_expr(volume)
# Compiled expression: safe_log_expr(turnover_rate)
# Compiled expression: ts_rank_expr(vwap, 11)
# Compiled expression: safe_mul_expr(twap, rolling_std_expr(safe_delta_expr(total_turnover, 13), const_3()))
# Compiled expression: ts_argmaxmin_expr(twap, 22)
# Compiled expression: ts_cov_expr(low, rolling_max_expr(total_turnover, 28), const_3())
# Compiled expression: rolling_std_expr(rank_sub_expr(close, low), const_5())
# Compiled expression: safe_log_expr(volume)
# Compiled expression: rolling_skew_expr(rolling_max_expr(total_turnover, 12), 15)
# Compiled expression: rolling_argmin_expr(safe_add_expr(high, open), const_5())
# Compiled expression: rolling_argmax_expr(rolling_prod_expr(safe_sub_expr(twap, high), const_3()), const_10())
# Compiled expression: rolling_sum_expr(turnover_rate, 25)
# Compiled expression: safe_delta_expr(safe_inverse_expr(safe_absolute_expr(twap)), const_3())
# Compiled expression: safe_add_expr(open, adj_return)
# Compiled expression: safe_sqrt_expr(safe_add_expr(high, open))
# Compiled expression: ts_argmaxmin_expr(low, 5)
# Compiled expression: rolling_kurt_expr(rolling_min_expr(rolling_mean_expr(total_turnover, 2), const_5()), const_3())
# Compiled expression: rolling_max_expr(safe_div_expr(ts_zscore_expr(turnover_rate, 22), safe_delay_expr(high, 18)), const_10())
# Compiled expression: rolling_argmax_expr(adj_return, 3)
# Compiled expression: safe_add_expr(adj_return, vwap)
# Compiled expression: x_rank_expr(rolling_mean_expr(vwap, 20))
# Compiled expression: rank_div_expr(turnover_rate, low)
# Compiled expression: ts_rank_expr(total_turnover, 14)
# Compiled expression: safe_add_expr(rolling_std_expr(ts_cov_expr(volume, close, 27), const_20()), ts_argmaxmin_expr(safe_absolute_expr(total_turnover), const_10()))
# Compiled expression: rolling_prod_expr(safe_mul_expr(safe_inverse_expr(total_turnover), rolling_argmin_expr(vwap, 25)), const_3())
# Compiled expression: ts_argmaxmin_expr(close, 23)
# Compiled expression: rolling_argmax_expr(vwap, 22)
# Compiled expression: rank_div_expr(ts_cov_expr(turnover_rate, vwap, 14), ts_zscore_expr(adj_return, 16))
# Compiled expression: rank_sub_expr(close, ts_zscore_expr(twap, 17))
# Compiled expression: safe_sub_expr(safe_inverse_expr(close), high)
# Compiled expression: safe_div_expr(close, volume)
# Compiled expression: safe_delay_expr(twap, 4)
# Compiled expression: rank_sub_expr(open, high)
# Compiled expression: rolling_min_expr(rolling_argmin_expr(rolling_skew_expr(turnover_rate, const_5()), const_3()), 7)
# Compiled expression: safe_sub_expr(ts_rank_expr(rolling_min_expr(turnover_rate, 7), const_20()), open)
# Compiled expression: safe_add_expr(total_turnover, low)
# Compiled expression: rank_div_expr(total_turnover, twap)
# Compiled expression: safe_log_expr(total_turnover)
# Compiled expression: safe_sub_expr(rolling_kurt_expr(close, 19), safe_sqrt_expr(vwap))
# Compiled expression: rolling_argmin_expr(safe_delta_expr(high, 3), const_5())
# Compiled expression: safe_sqrt_expr(close)
# Compiled expression: ts_argmaxmin_expr(close, 12)
# Compiled expression: ts_cov_expr(turnover_rate, twap, 12)
# Compiled expression: rolling_argmin_expr(safe_inverse_expr(safe_add_expr(turnover_rate, ts_rank_expr(adj_return, 11))), 20)
# Compiled expression: rolling_min_expr(safe_delta_expr(ts_rank_expr(total_turnover, 8), const_20()), const_3())
# Compiled expression: x_rank_expr(turnover_rate)
# Compiled expression: safe_absolute_expr(safe_sqrt_expr(adj_return))
# Compiled expression: rolling_kurt_expr(vwap, 10)
# Compiled expression: safe_inverse_expr(rolling_std_expr(ts_rank_expr(safe_mul_expr(low, vwap), const_5()), const_10()))
# Compiled expression: rolling_prod_expr(low, const_3())
# Compiled expression: ts_cov_expr(safe_absolute_expr(twap), rolling_argmin_expr(total_turnover, 22), 17)
# Compiled expression: safe_absolute_expr(safe_log_expr(rolling_skew_expr(rolling_kurt_expr(low, 9), const_20())))
# Compiled expression: sigmoid_expr(total_turnover)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 162
#     159 toolbox.register("select", tools.selTournament, tournsize=20)
#     161 ## 初始化种群
# --> 162 population = initialize_population_with_screening(toolbox, n_population=500, # 筛选初始化种群 informed init population
#     163                                                   fitness_threshold=0, length_threshold=9) # ideal ：icir=2 turnovers=0.3 fitness = 2/0.3
#     164 hof = tools.HallOfFame(100, similar=np.array_equal)
#     166 # 多目标统计
#     167 # stats_multi = tools.Statistics(lambda ind: ind.fitness.values)
#     168 # stats_multi.register("ICIRoTO_avg", lambda population: np.mean([ind.fitness.values[0] for ind in population]))
#    (...)
#     173 # stats_multi.register("len_max", lambda population: np.max([ind.fitness.values[1] for ind in population]))
#     174 # stats_multi.register("len_min", lambda population: np.min([ind.fitness.values[1] for ind in population]))
#
# Cell In[41], line 123, in initialize_population_with_screening(toolbox, n_population, fitness_threshold, length_threshold)
#     120         ind.fitness.values = (0.0,)
#     121         fitness_and_len.append((ind, 0.0,))  # 长度设大，保证筛掉
# --> 123 filtered_population = [
#     124     ind for ind, rot, length in fitness_and_len
#     125     if (rot >= fitness_threshold and length <= length_threshold)
#     126 ]
#     128 print(f"筛选后剩余 {len(filtered_population)} 个个体")
#     130 if len(filtered_population) >= n_population:
#
# Cell In[41], line 123, in <listcomp>(.0)
#     120         ind.fitness.values = (0.0,)
#     121         fitness_and_len.append((ind, 0.0,))  # 长度设大，保证筛掉
# --> 123 filtered_population = [
#     124     ind for ind, rot, length in fitness_and_len
#     125     if (rot >= fitness_threshold and length <= length_threshold)
#     126 ]
#     128 print(f"筛选后剩余 {len(filtered_population)} 个个体")
#     130 if len(filtered_population) >= n_population:
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
if not logbook:
    print("Logbook is empty, no generations recorded.")
else:
    print("Logbook last entry:", logbook[-1])
    # print("[{}] best_score: {}".format(logbook[-1]['gen'], logbook[-1]['max','N/A']))  # Use 'max' instead of 'min'

# Print all individuals stored in Hall of Fame (hof)
print("Best Individuals in Hall of Fame:")
for ind in hof:
    print("Individual:", ind)
    print("Fitness:", ind.fitness.values)
    print("----------")

# %%
def plot_convergence(logbook, patience, delta):
    gen = logbook.select("gen")
    max_fitness = logbook.select("max")

    plt.figure(figsize=(12, 6))
    plt.plot(gen, max_fitness, label="Max Fitness (Validation Set)", marker='o')

    # 标记 early stopping 发生点
    best_fitness = -np.inf
    no_improve_count = 0
    stop_gen = None

    for i in range(len(max_fitness)):
        if max_fitness[i] > best_fitness + delta:
            best_fitness = max_fitness[i]
            no_improve_count = 0
        else:
            no_improve_count += 1

        if no_improve_count >= patience:
            stop_gen = gen[i]
            break

    if stop_gen is not None:
        plt.axvline(x=stop_gen, color='r', linestyle='--', label=f'Early Stopping at Gen {stop_gen}')
        plt.scatter(stop_gen, max_fitness[gen.index(stop_gen)], color='red', zorder=5)

    plt.xlabel("Generation")
    plt.ylabel("Max Fitness (Validation Set ICIR)")
    plt.title("GP Convergence on Validation Set with Early Stopping")
    plt.legend()
    plt.grid(True)
    plt.show()
    
plot_convergence(logbook, patience=10, delta=1e-4)
