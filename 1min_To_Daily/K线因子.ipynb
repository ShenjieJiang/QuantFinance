# %%
import import_ipynb
import oss2
from setting import SETTINGS
import pickle
import pandas as pd
import os
import io
from dateutil import parser
import datetime
import pandas as pd
from fastparquet import write
from pathlib import  Path
from oss_handler import OssClient
import sys, os
import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt
from pylab import mpl
import seaborn as sns
from sklearn.linear_model import LinearRegression
import datetime
from datetime import datetime, timedelta
from oss2.exceptions import NoSuchKey
import warnings

warnings.filterwarnings('ignore')

AccessKeyId = SETTINGS["oss.accesskey"]
AccessKeySecret = SETTINGS["oss.secret"]
BucketName = SETTINGS["oss.bucketname"]
Endpoint = SETTINGS["oss.endpoint"]


class newBytes(io.BytesIO):
    def close(self):
        pass


class OssClient(object):
    __instance = None
    __first_init = False

    # 单例模式
    def __new__(cls, *args, **kwargs):
        if not cls.__instance:
            cls.__instance = super().__new__(cls)
        return cls.__instance

    def __init__(self):
        cls = self.__class__
        if not cls.__first_init:
            self.auth = oss2.Auth(AccessKeyId, AccessKeySecret)
            self.bucket = oss2.Bucket(self.auth, Endpoint, BucketName)
            cls.__first_init = True


    def upload_file_from_fileobj(self, object_name, local_file_path):
        """
            upload_file_from_fileobj方法：上传文件对象到oss存储空间, 该方法可用于我们从上游服务接收了图片参数，然后以二进制形式读文件，上传到oss存储空间指定位置（abc/efg/00），
        当然也可以将本地文件上传到oss我们的bucket. 其中fileobj不止可以是文件对象，也可以是本地文件路径。 put_object方法底层仍是RESTful API的调用，可以指定headers，规定Content-Type等内容
        """
        # 判断bucket中文件是否存在，也可以不判断，会上传更新
        #exist = self.bucket.object_exists(object_name) #<yourObjectName>
        #if exist:
        #    return True
        with open(local_file_path, 'rb') as fileobj:
            result = self.bucket.put_object(object_name, fileobj) #<yourObjectName>
        if result.status == 200:
            return True
        else:
            return False

    def upload_pickle_data(self,df, target_path, *args, report_date=None):
        if isinstance(report_date, datetime.date):
            d = report_date.strftime("%Y-%m-%d")
        if isinstance(report_date, str):
            d = parser.parse(report_date).strftime("%Y-%m-%d")
        if args:
            d = [arg for arg in args][0]
        pickle_buffer = io.BytesIO()
        pickle.dump(df, pickle_buffer)
        target_file_key = os.path.join(target_path, '{}.pkl'.format(d)).replace("\\","/")
        result = self.bucket.put_object(target_file_key, pickle_buffer.getvalue())
        if result.status == 200:
            return True
        else:
            return False


    def list_files(self,prefix = None):
        res = []
        for object_info in oss2.ObjectIterator(self.bucket,prefix):
            print(object_info.key)
            res.append(object_info.key)
        return res

    def upload_parquet_data(self,df, target_path, *args, report_date=None):
        if isinstance(report_date, datetime.date):
            d = report_date.strftime("%Y-%m-%d")
        if isinstance(report_date, str):
            d = parser.parse(report_date).strftime("%Y-%m-%d")
        if args:
            d = [arg for arg in args][0]
        target_file_key = os.path.join(target_path, '{}.parquet'.format(d)).replace("\\","/")
        mem_buffer = newBytes()
        df.to_parquet('noname', engine='fastparquet', open_with=lambda x, y: mem_buffer)
        result = self.bucket.put_object(target_file_key, mem_buffer.getvalue())
        #f = Path(os.getcwd())/'tmp.parquet'
        #write(f, df)
        #with open(f, 'rb') as fileobj:
        #    result = self.bucket.put_object(target_file_key, fileobj)
        #os.remove(f)
        if result.status == 200:
            return True
        else:
            return False

    def save_data_to_pickle(self,df, file_dir_path, *args,report_date=None):
        if isinstance(report_date, datetime.date):
            d = report_date.strftime("%Y-%m-%d")
        if isinstance(report_date, str):
            d = parser.parse(report_date).strftime("%Y-%m-%d")
        if args:
            d = [arg for arg in args][0]
        target_file_key = os.path.join(file_dir_path, '{}.pkl'.format(d))
        with open(target_file_key, 'wb') as f:
            pickle.dump(df, f)

    def save_data_to_parquet(self,df, file_dir_path, *args,report_date=None):
        if isinstance(report_date, datetime.date):
            d = report_date.strftime("%Y-%m-%d")
        if isinstance(report_date, str):
            d = parser.parse(report_date).strftime("%Y-%m-%d")
        if args:
            d = [arg for arg in args][0]
        target_file_key = os.path.join(file_dir_path, f'{d}.parquet')
        df.to_parquet(target_file_key)


    def read_oss_pickle_file(self,object_name):
        """
            download_file_to_fileobj：下载文件到文件流对象。由于get_object接口返回的是一个stream流，需要执行read()后才能计算出返回Object数据的CRC checksum，因此需要在调用该接口后做CRC校验。
        """
        object_stream = self.bucket.get_object(object_name) #<yourObjectName>
        result = object_stream.read()
        if object_stream.client_crc != object_stream.server_crc:
            print("The CRC checksum between client and server is inconsistent!")
            result = None
        return pickle.loads(result)

    def read_oss_parquet_file(self,object_name):
        """
            download_file_to_fileobj：下载文件到文件流对象。由于get_object接口返回的是一个stream流，需要执行read()后才能计算出返回Object数据的CRC checksum，因此需要在调用该接口后做CRC校验。
        """
        object_stream = self.bucket.get_object(object_name) #<yourObjectName>
        result = object_stream.read()
        i = io.BytesIO(result)
        if object_stream.client_crc != object_stream.server_crc:
            print("The CRC checksum between client and server is inconsistent!")
            result = None
        return pd.read_parquet(i)


    def download_file_to_loaclfilepath(self, object_name, local_file_path):
        """
            download_file_to_loaclfilepath：下载文件到本地路径。get_object和get_object_to_file的区别是前者是获取文件流实例，可用于代码处理和远程调用参赛。后者是存储到本地路径，返回的是一个http状态的json结果
        """
        result = self.bucket.get_object_to_file(object_name, local_file_path) # ('<yourObjectName>', '<yourLocalFile>')
        if result.status == 200:
            return True
        else:
            return False

    def generate_temporary_download_url(self,object_name):
        """
            generate_temporary_download_url: 生成加签的临时URL以供授信用户下载。一般在实际业务中，我们是提供给调用方一个临时下载链接，来让其获取文件数据，而不是直接使用以上暴露AccessKeyId和AccessKeySecret的方法。
            因此一般我们会存储某条数据oss的路径（<yourObjectName>）与调用方某个唯一标识的对应关系（如手机号身份证号），在调用方请求时，通过该标识获取其数据的oss文件路径（<yourObjectName>），
            然后制定过期时间，为其生成临时下载链接
            http://bucketname.oss-ap-south-1.aliyuncs.com/abc/efg/0?OSSAccessKeyId=LTA************oN9&Expires=1604638842&Signature=tPgvWz*************Uk%3D
        """
        res_temporary_url = self.bucket.sign_url('GET', object_name, 60, slash_safe=True)
        return res_temporary_url

oss_client = OssClient()
# Out:
# importing Jupyter notebook from setting.ipynb
# importing Jupyter notebook from oss_handler.ipynb
# LTAI5tN7V51xtxUmaKxmRsWo rmqsMszRtvurcckVMD9M14riQYshi6 2nd-data oss-cn-shenzhen.aliyuncs.com

# %%
#导入数据 
def k1min_data_process(date_str):
    k1min= oss_client.read_oss_parquet_file(f'ad_hoc_prod/1min_cs/{date_str}.parquet')
    k1min = k1min.sort_values(by=["RIC", "TIME"])
    K1min = k1min.reset_index(drop=True)
    k1min['RETURN'] = k1min['CLOSE']/k1min['OPEN'] - 1
    k1min = k1min.rename(columns={'RIC': 'ticker', 'DATE': 'date'})
    return k1min

# %%
#尾盘半小时动量
def mmt_last30min(single_day_data):
    
    ### 公式函数
    df = single_day_data.groupby('ticker').tail(31)
    df = df.groupby(['ticker', 'date'])['CLOSE'].apply(lambda x: x.iloc[-1] / x.iloc[0] - 1)
    ### 公式函数
    
    df = pd.DataFrame(df)
    df = df.reset_index()
    
    df = df.pivot(index='date', columns='ticker', values='CLOSE')
    return df

# %%
single_day_data = k1min_data_process(date)

# %%
cal_factor = mmt_last30min(single_day_data)

# %%
cal_factor
# Out:
# ticker        000001    000002    000004  000005    000006    000007  \
# date
# 2017-01-03  0.001093  0.000483 -0.001348     0.0  0.001035  0.003846
#
# ticker        000008    000009    000010    000011  ...  603986    603987  \
# date                                                ...
# 2017-01-03  0.001072 -0.005703  0.005161  0.004663  ...     0.0  0.002712
#
# ticker        603988    603989   603990    603993    603996    603997  \
# date
# 2017-01-03  0.012089 -0.002942 -0.00915  0.002674  0.000988  0.004073
#
# ticker       603998    603999
# date
# 2017-01-03 -0.00167  0.008389
#
# [1 rows x 3039 columns]

# %%
start_date = '2017-01-03'
end_date = '2025-01-04'
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

#尾盘半小时动量
def mmt_last30min(single_day_data):
    
    ### 公式函数
    df = single_day_data.groupby('ticker').tail(31)
    df = df.groupby(['ticker', 'date'])['CLOSE'].apply(lambda x: x.iloc[-1] / x.iloc[0] - 1)
    ### 公式函数
    
    df = pd.DataFrame(df)
    df = df.reset_index()
    
    df = df.pivot(index='date', columns='ticker', values='CLOSE')
    return df
final_df = pd.DataFrame()

for date in date_range:
    date_str = date.date().strftime('%Y-%m-%d')
 
    try:
        single_day_data = k1min_data_process(date_str)

        ### 公式函数
        cal_factor = mmt_last30min(single_day_data)
        ### 公式函数

        final_df = pd.concat([final_df, cal_factor])
        
    except NoSuchKey:
        # 捕获 NoSuchKey 异常并跳过该日期
        print(f"File for date {date_str} does not exist. Skipping...")
        continue
        
final_df = -1*final_df 
final_df.to_pickle('D:/redata/factor/mmt_last30min@factor.pkl')
# Out:
# File for date 2017-01-07 does not exist. Skipping...
# File for date 2017-01-08 does not exist. Skipping...
# File for date 2017-01-14 does not exist. Skipping...
# File for date 2017-01-15 does not exist. Skipping...
# File for date 2017-01-21 does not exist. Skipping...
# File for date 2017-01-22 does not exist. Skipping...
# File for date 2017-01-27 does not exist. Skipping...
# File for date 2017-01-28 does not exist. Skipping...
# File for date 2017-01-29 does not exist. Skipping...
# File for date 2017-01-30 does not exist. Skipping...
# File for date 2017-01-31 does not exist. Skipping...
# File for date 2017-02-01 does not exist. Skipping...
# File for date 2017-02-02 does not exist. Skipping...
# File for date 2017-02-04 does not exist. Skipping...
# File for date 2017-02-05 does not exist. Skipping...
# File for date 2017-02-11 does not exist. Skipping...
# File for date 2017-02-12 does not exist. Skipping...
# File for date 2017-02-18 does not exist. Skipping...
# File for date 2017-02-19 does not exist. Skipping...
# File for date 2017-02-25 does not exist. Skipping...
# File for date 2017-02-26 does not exist. Skipping...
# File for date 2017-03-04 does not exist. Skipping...
# File for date 2017-03-05 does not exist. Skipping...
# File for date 2017-03-11 does not exist. Skipping...
# File for date 2017-03-12 does not exist. Skipping...
# File for date 2017-03-18 does not exist. Skipping...
# File for date 2017-03-19 does not exist. Skipping...
# File for date 2017-03-25 does not exist. Skipping...
# File for date 2017-03-26 does not exist. Skipping...
# File for date 2017-04-01 does not exist. Skipping...
# File for date 2017-04-02 does not exist. Skipping...
# File for date 2017-04-03 does not exist. Skipping...
# File for date 2017-04-04 does not exist. Skipping...
# File for date 2017-04-08 does not exist. Skipping...
# File for date 2017-04-09 does not exist. Skipping...
# File for date 2017-04-15 does not exist. Skipping...
# File for date 2017-04-16 does not exist. Skipping...
# File for date 2017-04-22 does not exist. Skipping...
# File for date 2017-04-23 does not exist. Skipping...
# File for date 2017-04-29 does not exist. Skipping...
# File for date 2017-04-30 does not exist. Skipping...
# File for date 2017-05-01 does not exist. Skipping...
# File for date 2017-05-06 does not exist. Skipping...
# File for date 2017-05-07 does not exist. Skipping...
# File for date 2017-05-13 does not exist. Skipping...
# File for date 2017-05-14 does not exist. Skipping...
# File for date 2017-05-20 does not exist. Skipping...
# File for date 2017-05-21 does not exist. Skipping...
# File for date 2017-05-27 does not exist. Skipping...
# File for date 2017-05-28 does not exist. Skipping...
# File for date 2017-05-29 does not exist. Skipping...
# File for date 2017-05-30 does not exist. Skipping...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 11
#       8 date_str = date.date().strftime('%Y-%m-%d')
#      10 try:
# ---> 11     single_day_data = k1min_data_process(date_str)
#      13     ### 公式函数
#      14     cal_factor = mmt_last30min(single_day_data)
#
# Cell In[2], line 5, in k1min_data_process(date_str)
#       4 def k1min_data_process(date_str):
# ----> 5     k1min= oss_client.read_oss_parquet_file(f'ad_hoc_prod/1min_cs/{date_str}.parquet')
#       6     k1min = k1min.sort_values(by=["RIC", "TIME"])
#       7     K1min = k1min.reset_index(drop=True)
#
# Cell In[1], line 156, in OssClient.read_oss_parquet_file(self, object_name)
#     152 """
#     153     download_file_to_fileobj：下载文件到文件流对象。由于get_object接口返回的是一个stream流，需要执行read()后才能计算出返回Object数据的CRC checksum，因此需要在调用该接口后做CRC校验。
#     154 """
#     155 object_stream = self.bucket.get_object(object_name) #<yourObjectName>
# --> 156 result = object_stream.read()
#     157 i = io.BytesIO(result)
#     158 if object_stream.client_crc != object_stream.server_crc:
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\oss2\models.py:313, in GetObjectResult.read(self, amt)
#     312 def read(self, amt=None):
# --> 313     return self.stream.read(amt)
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\oss2\utils.py:436, in _FileLikeAdapter.read(self, amt)
#     433     else:
#     434         real_discard = self.discard
# --> 436 _invoke_crc_callback(self.crc_callback, content, real_discard)
#     437 content = _invoke_cipher_callback(self.cipher_callback, content, real_discard)
#     439 self.discard -= real_discard
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\oss2\utils.py:329, in _invoke_crc_callback(crc_callback, content, discard)
#     327 def _invoke_crc_callback(crc_callback, content, discard=0):
#     328     if crc_callback:
# --> 329         crc_callback(content[discard:])
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\oss2\utils.py:538, in Crc64.__call__(self, data)
#     537 def __call__(self, data):
# --> 538     self.update(data)
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\oss2\utils.py:541, in Crc64.update(self, data)
#     540 def update(self, data):
# --> 541     self.crc64.update(data)
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\crcmod\crcmod.py:152, in Crc.update(self, data)
#     148 def update(self, data):
#     149     '''Update the current CRC value using the string specified as the data
#     150     parameter.
#     151     '''
# --> 152     self.crcValue = self._crc(data, self.crcValue)
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\crcmod\crcmod.py:435, in _mkCrcFun.<locals>.crcfun(data, crc, table, fun)
#     434 def crcfun(data, crc=initCrc, table=_table, fun=_fun):
# --> 435     return xorOut ^ fun(data, xorOut ^ crc, table)
#
# File ~\Anaconda3\envs\nlp\lib\site-packages\crcmod\_crcfunpy.py:105, in _crc64r(data, crc, table)
#     103 crc = crc & 0xFFFFFFFFFFFFFFFF
#     104 for x in mv.tobytes():
# --> 105     crc = table[x ^ (crc & 0xFF)] ^ (crc >> 8)
#     106 return crc
#
# KeyboardInterrupt:

# %%
# 最大20vulume的mmt
def mmt_top20_volume(single_day_data):

    ### 公式函数
    df = (
        single_day_data.assign(vol_rank=lambda x: x.groupby(['ticker', 'date'])['VOL']
        .transform(lambda s: s.rank(method='first', ascending=False))).query('vol_rank <= 20')
        .groupby(['ticker', 'date'])['RETURN']
        .sum()
        .reset_index()
        .drop(columns=['vol_rank'], errors='ignore')
    )
    ### 公式函数
    df = pd.DataFrame(df)
    df = df.reset_index()
    df = df.rename(columns={df.columns[-1]: 'factor'})
    df = df.pivot(index='date', columns='ticker', values='factor')
    return df
    
##多天   
start_date = '2020-01-03'
end_date = '2025-01-04'
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

final_df = pd.DataFrame()

for date in date_range:
    date_str = date.date().strftime('%Y-%m-%d')
 
    try:
        single_day_data = k1min_data_process(date_str)

        ### 公式函数
        cal_factor = mmt_top20_volume(single_day_data)
        ### 公式函数

        final_df = pd.concat([final_df, cal_factor])
        
    except NoSuchKey:
        # 捕获 NoSuchKey 异常并跳过该日期
        print(f"File for date {date_str} does not exist. Skipping...")
        continue
        
final_df = -1*final_df 
final_df.to_pickle('D:/redata/factor/mmt_last30min@factor.pkl') #如果错过了读这个文件先
# Out:
# File for date 2020-01-04 does not exist. Skipping...
# File for date 2020-01-05 does not exist. Skipping...
# File for date 2020-01-11 does not exist. Skipping...
# File for date 2020-01-12 does not exist. Skipping...
# File for date 2020-01-18 does not exist. Skipping...
# File for date 2020-01-19 does not exist. Skipping...
# File for date 2020-01-24 does not exist. Skipping...
# File for date 2020-01-25 does not exist. Skipping...
# File for date 2020-01-26 does not exist. Skipping...
# File for date 2020-01-27 does not exist. Skipping...
# File for date 2020-01-28 does not exist. Skipping...
# File for date 2020-01-29 does not exist. Skipping...
# File for date 2020-01-30 does not exist. Skipping...
# File for date 2020-01-31 does not exist. Skipping...
# File for date 2020-02-01 does not exist. Skipping...
# File for date 2020-02-02 does not exist. Skipping...
# File for date 2020-02-08 does not exist. Skipping...
# File for date 2020-02-09 does not exist. Skipping...
# File for date 2020-02-15 does not exist. Skipping...
# File for date 2020-02-16 does not exist. Skipping...
# File for date 2020-02-22 does not exist. Skipping...
# File for date 2020-02-23 does not exist. Skipping...
# File for date 2020-02-29 does not exist. Skipping...
# File for date 2020-03-01 does not exist. Skipping...
# File for date 2020-03-07 does not exist. Skipping...
# File for date 2020-03-08 does not exist. Skipping...
# File for date 2020-03-14 does not exist. Skipping...
# File for date 2020-03-15 does not exist. Skipping...
# File for date 2020-03-21 does not exist. Skipping...
# File for date 2020-03-22 does not exist. Skipping...
# File for date 2020-03-28 does not exist. Skipping...
# File for date 2020-03-29 does not exist. Skipping...
# File for date 2020-04-04 does not exist. Skipping...
# File for date 2020-04-05 does not exist. Skipping...
# File for date 2020-04-06 does not exist. Skipping...
# File for date 2020-04-11 does not exist. Skipping...
# File for date 2020-04-12 does not exist. Skipping...
# File for date 2020-04-18 does not exist. Skipping...
# File for date 2020-04-19 does not exist. Skipping...
# File for date 2020-04-25 does not exist. Skipping...
# File for date 2020-04-26 does not exist. Skipping...
# File for date 2020-05-01 does not exist. Skipping...
# File for date 2020-05-02 does not exist. Skipping...
# File for date 2020-05-03 does not exist. Skipping...
# File for date 2020-05-04 does not exist. Skipping...
# File for date 2020-05-05 does not exist. Skipping...
# File for date 2020-05-09 does not exist. Skipping...
# File for date 2020-05-10 does not exist. Skipping...
# File for date 2020-05-16 does not exist. Skipping...
# File for date 2020-05-17 does not exist. Skipping...
# File for date 2020-05-23 does not exist. Skipping...
# File for date 2020-05-24 does not exist. Skipping...
# File for date 2020-05-30 does not exist. Skipping...
# File for date 2020-05-31 does not exist. Skipping...
# File for date 2020-06-06 does not exist. Skipping...
# File for date 2020-06-07 does not exist. Skipping...
# File for date 2020-06-13 does not exist. Skipping...
# File for date 2020-06-14 does not exist. Skipping...
# File for date 2020-06-20 does not exist. Skipping...
# File for date 2020-06-21 does not exist. Skipping...
# File for date 2020-06-25 does not exist. Skipping...
# File for date 2020-06-26 does not exist. Skipping...
# File for date 2020-06-27 does not exist. Skipping...
# File for date 2020-06-28 does not exist. Skipping...
# File for date 2020-07-04 does not exist. Skipping...
# File for date 2020-07-05 does not exist. Skipping...
# File for date 2020-07-11 does not exist. Skipping...
# File for date 2020-07-12 does not exist. Skipping...
# File for date 2020-07-18 does not exist. Skipping...
# File for date 2020-07-19 does not exist. Skipping...
# File for date 2020-07-25 does not exist. Skipping...
# File for date 2020-07-26 does not exist. Skipping...
# File for date 2020-08-01 does not exist. Skipping...
# File for date 2020-08-02 does not exist. Skipping...
# File for date 2020-08-08 does not exist. Skipping...
# File for date 2020-08-09 does not exist. Skipping...
# File for date 2020-08-15 does not exist. Skipping...
# File for date 2020-08-16 does not exist. Skipping...
# File for date 2020-08-22 does not exist. Skipping...
# File for date 2020-08-23 does not exist. Skipping...
# File for date 2020-08-29 does not exist. Skipping...
# File for date 2020-08-30 does not exist. Skipping...
# File for date 2020-09-05 does not exist. Skipping...
# File for date 2020-09-06 does not exist. Skipping...
# File for date 2020-09-12 does not exist. Skipping...
# File for date 2020-09-13 does not exist. Skipping...
# File for date 2020-09-19 does not exist. Skipping...
# File for date 2020-09-20 does not exist. Skipping...
# File for date 2020-09-26 does not exist. Skipping...
# File for date 2020-09-27 does not exist. Skipping...
# File for date 2020-10-01 does not exist. Skipping...
# File for date 2020-10-02 does not exist. Skipping...
# File for date 2020-10-03 does not exist. Skipping...
# File for date 2020-10-04 does not exist. Skipping...
# File for date 2020-10-05 does not exist. Skipping...
# File for date 2020-10-06 does not exist. Skipping...
# File for date 2020-10-07 does not exist. Skipping...
# File for date 2020-10-08 does not exist. Skipping...
# File for date 2020-10-10 does not exist. Skipping...
# File for date 2020-10-11 does not exist. Skipping...
# File for date 2020-10-17 does not exist. Skipping...
# File for date 2020-10-18 does not exist. Skipping...
# File for date 2020-10-24 does not exist. Skipping...
# File for date 2020-10-25 does not exist. Skipping...
# File for date 2020-10-31 does not exist. Skipping...
# File for date 2020-11-01 does not exist. Skipping...
# File for date 2020-11-07 does not exist. Skipping...
# File for date 2020-11-08 does not exist. Skipping...
# File for date 2020-11-14 does not exist. Skipping...
# File for date 2020-11-15 does not exist. Skipping...
# File for date 2020-11-21 does not exist. Skipping...
# File for date 2020-11-22 does not exist. Skipping...
# File for date 2020-11-28 does not exist. Skipping...
# File for date 2020-11-29 does not exist. Skipping...
# File for date 2020-12-05 does not exist. Skipping...
# File for date 2020-12-06 does not exist. Skipping...
# File for date 2020-12-12 does not exist. Skipping...
# File for date 2020-12-13 does not exist. Skipping...
# File for date 2020-12-19 does not exist. Skipping...
# File for date 2020-12-20 does not exist. Skipping...
# File for date 2020-12-26 does not exist. Skipping...
# File for date 2020-12-27 does not exist. Skipping...
# File for date 2021-01-01 does not exist. Skipping...
# File for date 2021-01-02 does not exist. Skipping...
# File for date 2021-01-03 does not exist. Skipping...
# File for date 2021-01-09 does not exist. Skipping...
# File for date 2021-01-10 does not exist. Skipping...
# File for date 2021-01-16 does not exist. Skipping...
# File for date 2021-01-17 does not exist. Skipping...
# File for date 2021-01-23 does not exist. Skipping...
# File for date 2021-01-24 does not exist. Skipping...
# File for date 2021-01-30 does not exist. Skipping...
# File for date 2021-01-31 does not exist. Skipping...
# File for date 2021-02-06 does not exist. Skipping...
# File for date 2021-02-07 does not exist. Skipping...
# File for date 2021-02-11 does not exist. Skipping...
# File for date 2021-02-12 does not exist. Skipping...
# File for date 2021-02-13 does not exist. Skipping...
# File for date 2021-02-14 does not exist. Skipping...
# File for date 2021-02-15 does not exist. Skipping...
# File for date 2021-02-16 does not exist. Skipping...
# File for date 2021-02-17 does not exist. Skipping...
# File for date 2021-02-20 does not exist. Skipping...
# File for date 2021-02-21 does not exist. Skipping...
# File for date 2021-02-27 does not exist. Skipping...
# File for date 2021-02-28 does not exist. Skipping...
# File for date 2021-03-06 does not exist. Skipping...
# File for date 2021-03-07 does not exist. Skipping...
# File for date 2021-03-13 does not exist. Skipping...
# File for date 2021-03-14 does not exist. Skipping...
# File for date 2021-03-20 does not exist. Skipping...
# File for date 2021-03-21 does not exist. Skipping...
# File for date 2021-03-27 does not exist. Skipping...
# File for date 2021-03-28 does not exist. Skipping...
# File for date 2021-04-03 does not exist. Skipping...
# File for date 2021-04-04 does not exist. Skipping...
# File for date 2021-04-05 does not exist. Skipping...
# File for date 2021-04-10 does not exist. Skipping...
# File for date 2021-04-11 does not exist. Skipping...
# File for date 2021-04-17 does not exist. Skipping...
# File for date 2021-04-18 does not exist. Skipping...
# File for date 2021-04-24 does not exist. Skipping...
# File for date 2021-04-25 does not exist. Skipping...
# File for date 2021-05-01 does not exist. Skipping...
# File for date 2021-05-02 does not exist. Skipping...
# File for date 2021-05-03 does not exist. Skipping...
# File for date 2021-05-04 does not exist. Skipping...
# File for date 2021-05-05 does not exist. Skipping...
# File for date 2021-05-08 does not exist. Skipping...
# File for date 2021-05-09 does not exist. Skipping...
# File for date 2021-05-15 does not exist. Skipping...
# File for date 2021-05-16 does not exist. Skipping...
# File for date 2021-05-22 does not exist. Skipping...
# File for date 2021-05-23 does not exist. Skipping...
# File for date 2021-05-29 does not exist. Skipping...
# File for date 2021-05-30 does not exist. Skipping...
# File for date 2021-06-05 does not exist. Skipping...
# File for date 2021-06-06 does not exist. Skipping...
# File for date 2021-06-12 does not exist. Skipping...
# File for date 2021-06-13 does not exist. Skipping...
# File for date 2021-06-14 does not exist. Skipping...
# File for date 2021-06-19 does not exist. Skipping...
# File for date 2021-06-20 does not exist. Skipping...
# File for date 2021-06-26 does not exist. Skipping...
# File for date 2021-06-27 does not exist. Skipping...
# File for date 2021-07-03 does not exist. Skipping...
# File for date 2021-07-04 does not exist. Skipping...
# File for date 2021-07-10 does not exist. Skipping...
# File for date 2021-07-11 does not exist. Skipping...
# File for date 2021-07-17 does not exist. Skipping...
# File for date 2021-07-18 does not exist. Skipping...
# File for date 2021-07-24 does not exist. Skipping...
# File for date 2021-07-25 does not exist. Skipping...
# File for date 2021-07-31 does not exist. Skipping...
# File for date 2021-08-01 does not exist. Skipping...
# File for date 2021-08-07 does not exist. Skipping...
# File for date 2021-08-08 does not exist. Skipping...
# File for date 2021-08-14 does not exist. Skipping...
# File for date 2021-08-15 does not exist. Skipping...
# File for date 2021-08-21 does not exist. Skipping...
# File for date 2021-08-22 does not exist. Skipping...
# File for date 2021-08-28 does not exist. Skipping...
# File for date 2021-08-29 does not exist. Skipping...
# File for date 2021-09-04 does not exist. Skipping...
# File for date 2021-09-05 does not exist. Skipping...
# File for date 2021-09-11 does not exist. Skipping...
# File for date 2021-09-12 does not exist. Skipping...
# File for date 2021-09-18 does not exist. Skipping...
# File for date 2021-09-19 does not exist. Skipping...
# File for date 2021-09-20 does not exist. Skipping...
# File for date 2021-09-21 does not exist. Skipping...
# File for date 2021-09-25 does not exist. Skipping...
# File for date 2021-09-26 does not exist. Skipping...
# File for date 2021-10-01 does not exist. Skipping...
# File for date 2021-10-02 does not exist. Skipping...
# File for date 2021-10-03 does not exist. Skipping...
# File for date 2021-10-04 does not exist. Skipping...
# File for date 2021-10-05 does not exist. Skipping...
# File for date 2021-10-06 does not exist. Skipping...
# File for date 2021-10-07 does not exist. Skipping...
# File for date 2021-10-09 does not exist. Skipping...
# File for date 2021-10-10 does not exist. Skipping...
# File for date 2021-10-16 does not exist. Skipping...
# File for date 2021-10-17 does not exist. Skipping...
# File for date 2021-10-23 does not exist. Skipping...
# File for date 2021-10-24 does not exist. Skipping...
# File for date 2021-10-30 does not exist. Skipping...
# File for date 2021-10-31 does not exist. Skipping...
# File for date 2021-11-06 does not exist. Skipping...
# File for date 2021-11-07 does not exist. Skipping...
# File for date 2021-11-13 does not exist. Skipping...
# File for date 2021-11-14 does not exist. Skipping...
# File for date 2021-11-20 does not exist. Skipping...
# File for date 2021-11-21 does not exist. Skipping...
# File for date 2021-11-27 does not exist. Skipping...
# File for date 2021-11-28 does not exist. Skipping...
# File for date 2021-12-04 does not exist. Skipping...
# File for date 2021-12-05 does not exist. Skipping...
# File for date 2021-12-11 does not exist. Skipping...
# File for date 2021-12-12 does not exist. Skipping...
# File for date 2021-12-18 does not exist. Skipping...
# File for date 2021-12-19 does not exist. Skipping...
# File for date 2021-12-25 does not exist. Skipping...
# File for date 2021-12-26 does not exist. Skipping...
# File for date 2022-01-01 does not exist. Skipping...
# File for date 2022-01-02 does not exist. Skipping...
# File for date 2022-01-03 does not exist. Skipping...
# File for date 2022-01-08 does not exist. Skipping...
# File for date 2022-01-09 does not exist. Skipping...
# File for date 2022-01-15 does not exist. Skipping...
# File for date 2022-01-16 does not exist. Skipping...
# File for date 2022-01-22 does not exist. Skipping...
# File for date 2022-01-23 does not exist. Skipping...
# File for date 2022-01-29 does not exist. Skipping...
# File for date 2022-01-30 does not exist. Skipping...
# File for date 2022-01-31 does not exist. Skipping...
# File for date 2022-02-01 does not exist. Skipping...
# File for date 2022-02-02 does not exist. Skipping...
# File for date 2022-02-03 does not exist. Skipping...
# File for date 2022-02-04 does not exist. Skipping...
# File for date 2022-02-05 does not exist. Skipping...
# File for date 2022-02-06 does not exist. Skipping...
# File for date 2022-02-12 does not exist. Skipping...
# File for date 2022-02-13 does not exist. Skipping...
# File for date 2022-02-19 does not exist. Skipping...
# File for date 2022-02-20 does not exist. Skipping...
# File for date 2022-02-26 does not exist. Skipping...
# File for date 2022-02-27 does not exist. Skipping...
# File for date 2022-03-05 does not exist. Skipping...
# File for date 2022-03-06 does not exist. Skipping...
# File for date 2022-03-12 does not exist. Skipping...
# File for date 2022-03-13 does not exist. Skipping...
# File for date 2022-03-19 does not exist. Skipping...
# File for date 2022-03-20 does not exist. Skipping...
# File for date 2022-03-26 does not exist. Skipping...
# File for date 2022-03-27 does not exist. Skipping...
# File for date 2022-04-02 does not exist. Skipping...
# File for date 2022-04-03 does not exist. Skipping...
# File for date 2022-04-04 does not exist. Skipping...
# File for date 2022-04-05 does not exist. Skipping...
# File for date 2022-04-09 does not exist. Skipping...
# File for date 2022-04-10 does not exist. Skipping...
# File for date 2022-04-16 does not exist. Skipping...
# File for date 2022-04-17 does not exist. Skipping...
# File for date 2022-04-23 does not exist. Skipping...
# File for date 2022-04-24 does not exist. Skipping...
# File for date 2022-04-30 does not exist. Skipping...
# File for date 2022-05-01 does not exist. Skipping...
# File for date 2022-05-02 does not exist. Skipping...
# File for date 2022-05-03 does not exist. Skipping...
# File for date 2022-05-04 does not exist. Skipping...
# File for date 2022-05-07 does not exist. Skipping...
# File for date 2022-05-08 does not exist. Skipping...
# File for date 2022-05-14 does not exist. Skipping...
# File for date 2022-05-15 does not exist. Skipping...
# File for date 2022-05-21 does not exist. Skipping...
# File for date 2022-05-22 does not exist. Skipping...
# File for date 2022-05-28 does not exist. Skipping...
# File for date 2022-05-29 does not exist. Skipping...
# File for date 2022-06-03 does not exist. Skipping...
# File for date 2022-06-04 does not exist. Skipping...
# File for date 2022-06-05 does not exist. Skipping...
# File for date 2022-06-11 does not exist. Skipping...
# File for date 2022-06-12 does not exist. Skipping...
# File for date 2022-06-18 does not exist. Skipping...
# File for date 2022-06-19 does not exist. Skipping...
# File for date 2022-06-25 does not exist. Skipping...
# File for date 2022-06-26 does not exist. Skipping...
# File for date 2022-07-02 does not exist. Skipping...
# File for date 2022-07-03 does not exist. Skipping...
# File for date 2022-07-09 does not exist. Skipping...
# File for date 2022-07-10 does not exist. Skipping...
# File for date 2022-07-16 does not exist. Skipping...
# File for date 2022-07-17 does not exist. Skipping...
# File for date 2022-07-23 does not exist. Skipping...
# File for date 2022-07-24 does not exist. Skipping...
# File for date 2022-07-30 does not exist. Skipping...
# File for date 2022-07-31 does not exist. Skipping...
# File for date 2022-08-06 does not exist. Skipping...
# File for date 2022-08-07 does not exist. Skipping...
# File for date 2022-08-13 does not exist. Skipping...
# File for date 2022-08-14 does not exist. Skipping...
# File for date 2022-08-20 does not exist. Skipping...
# File for date 2022-08-21 does not exist. Skipping...
# File for date 2022-08-27 does not exist. Skipping...
# File for date 2022-08-28 does not exist. Skipping...
# File for date 2022-09-03 does not exist. Skipping...
# File for date 2022-09-04 does not exist. Skipping...
# File for date 2022-09-10 does not exist. Skipping...
# File for date 2022-09-11 does not exist. Skipping...
# File for date 2022-09-12 does not exist. Skipping...
# File for date 2022-09-17 does not exist. Skipping...
# File for date 2022-09-18 does not exist. Skipping...
# File for date 2022-09-24 does not exist. Skipping...
# File for date 2022-09-25 does not exist. Skipping...
# File for date 2022-10-01 does not exist. Skipping...
# File for date 2022-10-02 does not exist. Skipping...
# File for date 2022-10-03 does not exist. Skipping...
# File for date 2022-10-04 does not exist. Skipping...
# File for date 2022-10-05 does not exist. Skipping...
# File for date 2022-10-06 does not exist. Skipping...
# File for date 2022-10-07 does not exist. Skipping...
# File for date 2022-10-08 does not exist. Skipping...
# File for date 2022-10-09 does not exist. Skipping...
# File for date 2022-10-15 does not exist. Skipping...
# File for date 2022-10-16 does not exist. Skipping...
# File for date 2022-10-22 does not exist. Skipping...
# File for date 2022-10-23 does not exist. Skipping...
# File for date 2022-10-29 does not exist. Skipping...
# File for date 2022-10-30 does not exist. Skipping...
# File for date 2022-11-05 does not exist. Skipping...
# File for date 2022-11-06 does not exist. Skipping...
# File for date 2022-11-12 does not exist. Skipping...
# File for date 2022-11-13 does not exist. Skipping...
# File for date 2022-11-19 does not exist. Skipping...
# File for date 2022-11-20 does not exist. Skipping...
# File for date 2022-11-26 does not exist. Skipping...
# File for date 2022-11-27 does not exist. Skipping...
# File for date 2022-12-03 does not exist. Skipping...
# File for date 2022-12-04 does not exist. Skipping...
# File for date 2022-12-10 does not exist. Skipping...
# File for date 2022-12-11 does not exist. Skipping...
# File for date 2022-12-17 does not exist. Skipping...
# File for date 2022-12-18 does not exist. Skipping...
# File for date 2022-12-24 does not exist. Skipping...
# File for date 2022-12-25 does not exist. Skipping...
# File for date 2022-12-31 does not exist. Skipping...
# File for date 2023-01-01 does not exist. Skipping...
# File for date 2023-01-02 does not exist. Skipping...
# File for date 2023-01-07 does not exist. Skipping...
# File for date 2023-01-08 does not exist. Skipping...
# File for date 2023-01-14 does not exist. Skipping...
# File for date 2023-01-15 does not exist. Skipping...
# File for date 2023-01-21 does not exist. Skipping...
# File for date 2023-01-22 does not exist. Skipping...
# File for date 2023-01-23 does not exist. Skipping...
# File for date 2023-01-24 does not exist. Skipping...
# File for date 2023-01-25 does not exist. Skipping...
# File for date 2023-01-26 does not exist. Skipping...
# File for date 2023-01-27 does not exist. Skipping...
# File for date 2023-01-28 does not exist. Skipping...
# File for date 2023-01-29 does not exist. Skipping...
# File for date 2023-02-04 does not exist. Skipping...
# File for date 2023-02-05 does not exist. Skipping...
# File for date 2023-02-11 does not exist. Skipping...
# File for date 2023-02-12 does not exist. Skipping...
# File for date 2023-02-18 does not exist. Skipping...
# File for date 2023-02-19 does not exist. Skipping...
# File for date 2023-02-25 does not exist. Skipping...
# File for date 2023-02-26 does not exist. Skipping...
# File for date 2023-03-04 does not exist. Skipping...
# File for date 2023-03-05 does not exist. Skipping...
# File for date 2023-03-11 does not exist. Skipping...
# File for date 2023-03-12 does not exist. Skipping...
# File for date 2023-03-18 does not exist. Skipping...
# File for date 2023-03-19 does not exist. Skipping...
# File for date 2023-03-25 does not exist. Skipping...
# File for date 2023-03-26 does not exist. Skipping...
# File for date 2023-04-01 does not exist. Skipping...
# File for date 2023-04-02 does not exist. Skipping...
# File for date 2023-04-05 does not exist. Skipping...
# File for date 2023-04-08 does not exist. Skipping...
# File for date 2023-04-09 does not exist. Skipping...
# File for date 2023-04-15 does not exist. Skipping...
# File for date 2023-04-16 does not exist. Skipping...
# File for date 2023-04-22 does not exist. Skipping...
# File for date 2023-04-23 does not exist. Skipping...
# File for date 2023-04-29 does not exist. Skipping...
# File for date 2023-04-30 does not exist. Skipping...
# File for date 2023-05-01 does not exist. Skipping...
# File for date 2023-05-02 does not exist. Skipping...
# File for date 2023-05-03 does not exist. Skipping...
# File for date 2023-05-06 does not exist. Skipping...
# File for date 2023-05-07 does not exist. Skipping...
# File for date 2023-05-13 does not exist. Skipping...
# File for date 2023-05-14 does not exist. Skipping...
# File for date 2023-05-20 does not exist. Skipping...
# File for date 2023-05-21 does not exist. Skipping...
# File for date 2023-05-27 does not exist. Skipping...
# File for date 2023-05-28 does not exist. Skipping...
# File for date 2023-06-03 does not exist. Skipping...
# File for date 2023-06-04 does not exist. Skipping...
# File for date 2023-06-10 does not exist. Skipping...
# File for date 2023-06-11 does not exist. Skipping...
# File for date 2023-06-17 does not exist. Skipping...
# File for date 2023-06-18 does not exist. Skipping...
# File for date 2023-06-22 does not exist. Skipping...
# File for date 2023-06-23 does not exist. Skipping...
# File for date 2023-06-24 does not exist. Skipping...
# File for date 2023-06-25 does not exist. Skipping...
# File for date 2023-07-01 does not exist. Skipping...
# File for date 2023-07-02 does not exist. Skipping...
# File for date 2023-07-08 does not exist. Skipping...
# File for date 2023-07-09 does not exist. Skipping...
# File for date 2023-07-15 does not exist. Skipping...
# File for date 2023-07-16 does not exist. Skipping...
# File for date 2023-07-22 does not exist. Skipping...
# File for date 2023-07-23 does not exist. Skipping...
# File for date 2023-07-29 does not exist. Skipping...
# File for date 2023-07-30 does not exist. Skipping...
# File for date 2023-08-05 does not exist. Skipping...
# File for date 2023-08-06 does not exist. Skipping...
# File for date 2023-08-12 does not exist. Skipping...
# File for date 2023-08-13 does not exist. Skipping...
# File for date 2023-08-19 does not exist. Skipping...
# File for date 2023-08-20 does not exist. Skipping...
# File for date 2023-08-26 does not exist. Skipping...
# File for date 2023-08-27 does not exist. Skipping...
# File for date 2023-09-02 does not exist. Skipping...
# File for date 2023-09-03 does not exist. Skipping...
# File for date 2023-09-09 does not exist. Skipping...
# File for date 2023-09-10 does not exist. Skipping...
# File for date 2023-09-16 does not exist. Skipping...
# File for date 2023-09-17 does not exist. Skipping...
# File for date 2023-09-23 does not exist. Skipping...
# File for date 2023-09-24 does not exist. Skipping...
# File for date 2023-09-29 does not exist. Skipping...
# File for date 2023-09-30 does not exist. Skipping...
# File for date 2023-10-01 does not exist. Skipping...
# File for date 2023-10-02 does not exist. Skipping...
# File for date 2023-10-03 does not exist. Skipping...
# File for date 2023-10-04 does not exist. Skipping...
# File for date 2023-10-05 does not exist. Skipping...
# File for date 2023-10-06 does not exist. Skipping...
# File for date 2023-10-07 does not exist. Skipping...
# File for date 2023-10-08 does not exist. Skipping...
# File for date 2023-10-14 does not exist. Skipping...
# File for date 2023-10-15 does not exist. Skipping...
# File for date 2023-10-21 does not exist. Skipping...
# File for date 2023-10-22 does not exist. Skipping...
# File for date 2023-10-28 does not exist. Skipping...
# File for date 2023-10-29 does not exist. Skipping...
# File for date 2023-11-04 does not exist. Skipping...
# File for date 2023-11-05 does not exist. Skipping...
# File for date 2023-11-11 does not exist. Skipping...
# File for date 2023-11-12 does not exist. Skipping...
# File for date 2023-11-18 does not exist. Skipping...
# File for date 2023-11-19 does not exist. Skipping...
# File for date 2023-11-25 does not exist. Skipping...
# File for date 2023-11-26 does not exist. Skipping...
# File for date 2023-12-02 does not exist. Skipping...
# File for date 2023-12-03 does not exist. Skipping...
# File for date 2023-12-09 does not exist. Skipping...
# File for date 2023-12-10 does not exist. Skipping...
# File for date 2023-12-16 does not exist. Skipping...
# File for date 2023-12-17 does not exist. Skipping...
# File for date 2023-12-23 does not exist. Skipping...
# File for date 2023-12-24 does not exist. Skipping...
# File for date 2023-12-30 does not exist. Skipping...
# File for date 2023-12-31 does not exist. Skipping...
# File for date 2024-01-01 does not exist. Skipping...
# File for date 2024-01-06 does not exist. Skipping...
# File for date 2024-01-07 does not exist. Skipping...
# File for date 2024-01-13 does not exist. Skipping...
# File for date 2024-01-14 does not exist. Skipping...
# File for date 2024-01-20 does not exist. Skipping...
# File for date 2024-01-21 does not exist. Skipping...
# File for date 2024-01-27 does not exist. Skipping...
# File for date 2024-01-28 does not exist. Skipping...
# File for date 2024-02-03 does not exist. Skipping...
# File for date 2024-02-04 does not exist. Skipping...
# File for date 2024-02-09 does not exist. Skipping...
# File for date 2024-02-10 does not exist. Skipping...
# File for date 2024-02-11 does not exist. Skipping...
# File for date 2024-02-12 does not exist. Skipping...
# File for date 2024-02-13 does not exist. Skipping...
# File for date 2024-02-14 does not exist. Skipping...
# File for date 2024-02-15 does not exist. Skipping...
# File for date 2024-02-16 does not exist. Skipping...
# File for date 2024-02-17 does not exist. Skipping...
# File for date 2024-02-18 does not exist. Skipping...
# File for date 2024-02-24 does not exist. Skipping...
# File for date 2024-02-25 does not exist. Skipping...
# File for date 2024-03-02 does not exist. Skipping...
# File for date 2024-03-03 does not exist. Skipping...
# File for date 2024-03-09 does not exist. Skipping...
# File for date 2024-03-10 does not exist. Skipping...
# File for date 2024-03-16 does not exist. Skipping...
# File for date 2024-03-17 does not exist. Skipping...
# File for date 2024-03-23 does not exist. Skipping...
# File for date 2024-03-24 does not exist. Skipping...
# File for date 2024-03-30 does not exist. Skipping...
# File for date 2024-03-31 does not exist. Skipping...
# File for date 2024-04-04 does not exist. Skipping...
# File for date 2024-04-05 does not exist. Skipping...
# File for date 2024-04-06 does not exist. Skipping...
# File for date 2024-04-07 does not exist. Skipping...
# File for date 2024-04-13 does not exist. Skipping...
# File for date 2024-04-14 does not exist. Skipping...
# File for date 2024-04-20 does not exist. Skipping...
# File for date 2024-04-21 does not exist. Skipping...
# File for date 2024-04-27 does not exist. Skipping...
# File for date 2024-04-28 does not exist. Skipping...
# File for date 2024-05-01 does not exist. Skipping...
# File for date 2024-05-02 does not exist. Skipping...
# File for date 2024-05-03 does not exist. Skipping...
# File for date 2024-05-04 does not exist. Skipping...
# File for date 2024-05-05 does not exist. Skipping...
# File for date 2024-05-11 does not exist. Skipping...
# File for date 2024-05-12 does not exist. Skipping...
# File for date 2024-05-18 does not exist. Skipping...
# File for date 2024-05-19 does not exist. Skipping...
# File for date 2024-05-25 does not exist. Skipping...
# File for date 2024-05-26 does not exist. Skipping...
# File for date 2024-06-01 does not exist. Skipping...
# File for date 2024-06-02 does not exist. Skipping...
# File for date 2024-06-08 does not exist. Skipping...
# File for date 2024-06-09 does not exist. Skipping...
# File for date 2024-06-10 does not exist. Skipping...
# File for date 2024-06-15 does not exist. Skipping...
# File for date 2024-06-16 does not exist. Skipping...
# File for date 2024-06-22 does not exist. Skipping...
# File for date 2024-06-23 does not exist. Skipping...
# File for date 2024-06-29 does not exist. Skipping...
# File for date 2024-06-30 does not exist. Skipping...
# File for date 2024-07-06 does not exist. Skipping...
# File for date 2024-07-07 does not exist. Skipping...
# File for date 2024-07-13 does not exist. Skipping...
# File for date 2024-07-14 does not exist. Skipping...
# File for date 2024-07-20 does not exist. Skipping...
# File for date 2024-07-21 does not exist. Skipping...
# File for date 2024-07-27 does not exist. Skipping...
# File for date 2024-07-28 does not exist. Skipping...
# File for date 2024-08-03 does not exist. Skipping...
# File for date 2024-08-04 does not exist. Skipping...
# File for date 2024-08-10 does not exist. Skipping...
# File for date 2024-08-11 does not exist. Skipping...
# File for date 2024-08-17 does not exist. Skipping...
# File for date 2024-08-18 does not exist. Skipping...
# File for date 2024-08-24 does not exist. Skipping...
# File for date 2024-08-25 does not exist. Skipping...
# File for date 2024-08-31 does not exist. Skipping...
# File for date 2024-09-01 does not exist. Skipping...
# File for date 2024-09-07 does not exist. Skipping...
# File for date 2024-09-08 does not exist. Skipping...
# File for date 2024-09-14 does not exist. Skipping...
# File for date 2024-09-15 does not exist. Skipping...
# File for date 2024-09-16 does not exist. Skipping...
# File for date 2024-09-17 does not exist. Skipping...
# File for date 2024-09-21 does not exist. Skipping...
# File for date 2024-09-22 does not exist. Skipping...
# File for date 2024-09-28 does not exist. Skipping...
# File for date 2024-09-29 does not exist. Skipping...
# File for date 2024-10-01 does not exist. Skipping...
# File for date 2024-10-02 does not exist. Skipping...
# File for date 2024-10-03 does not exist. Skipping...
# File for date 2024-10-04 does not exist. Skipping...
# File for date 2024-10-05 does not exist. Skipping...
# File for date 2024-10-06 does not exist. Skipping...
# File for date 2024-10-07 does not exist. Skipping...
# File for date 2024-10-12 does not exist. Skipping...
# File for date 2024-10-13 does not exist. Skipping...
# File for date 2024-10-19 does not exist. Skipping...
# File for date 2024-10-20 does not exist. Skipping...
# File for date 2024-10-26 does not exist. Skipping...
# File for date 2024-10-27 does not exist. Skipping...
# File for date 2024-11-02 does not exist. Skipping...
# File for date 2024-11-03 does not exist. Skipping...
# File for date 2024-11-09 does not exist. Skipping...
# File for date 2024-11-10 does not exist. Skipping...
# File for date 2024-11-16 does not exist. Skipping...
# File for date 2024-11-17 does not exist. Skipping...
# File for date 2024-11-23 does not exist. Skipping...
# File for date 2024-11-24 does not exist. Skipping...
# File for date 2024-11-30 does not exist. Skipping...
# File for date 2024-12-01 does not exist. Skipping...
# File for date 2024-12-07 does not exist. Skipping...
# File for date 2024-12-08 does not exist. Skipping...
# File for date 2024-12-14 does not exist. Skipping...
# File for date 2024-12-15 does not exist. Skipping...
# File for date 2024-12-21 does not exist. Skipping...
# File for date 2024-12-22 does not exist. Skipping...
# File for date 2024-12-28 does not exist. Skipping...
# File for date 2024-12-29 does not exist. Skipping...
# File for date 2025-01-01 does not exist. Skipping...
# File for date 2025-01-04 does not exist. Skipping...

# %%
final_df.to_pickle('D:/redata/factor/mmt_top20_volume@factor.pkl')

# %%
mmt_last30min_today = mmt_last30min(k1min)
mmt_last30min_full_data = pd.read_pickle('D:/redata/factor/mmt_last30min@factor.pkl')
mmt_last30min_full_data =  pd.concat([mmt_last30min_full_data, mmt_last30min_today])
mmt_last30min_full_data.to_pickle('D:/redata/factor/mmt_last30min@factor.pkl')

mmt_last30min_std = -1 * mmt_last30min_full_data.rolling(20).std()
mmt_last30min_std.to_pickle('D:/redata/factor/mmt_last30min_std@factor.pkl')
